# %%
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from os.path import join

# %%
mypath = "results/prediction_pipeline_losses3"

# %%
for file in listdir(mypath):
    print(file)
# Out:
# test_acc_list_regnet.npy
# test_acc_list_humannet.npy
# train_loss_list_humannet.npy
# test_loss_list_regnet.npy
# test_loss_list_humannet.npy
# train_loss_list_regnet.npy
# train_loss_list_hetio.npy
# test_acc_list_funcoup.npy
# test_acc_list_genemania.npy
# train_loss_list_stringdb.npy
# test_loss_list_stringdb.npy
# test_acc_list_hetio.npy
# test_loss_list_genemania.npy
# test_loss_list_hetio.npy
# train_loss_list_funcoup.npy
# test_acc_list_stringdb.npy
# train_loss_list_genemania.npy
# test_loss_list_funcoup.npy

# %%
test_acc_list_regnet = np.load(join(mypath, "test_acc_list_regnet.npy"))
test_acc_list_humannet = np.load(join(mypath, "test_acc_list_humannet.npy"))
train_loss_list_humannet = np.load(join(mypath, "train_loss_list_humannet.npy"))
test_loss_list_regnet = np.load(join(mypath, "test_loss_list_regnet.npy"))
test_loss_list_humannet = np.load(join(mypath, "test_loss_list_humannet.npy"))
train_loss_list_regnet = np.load(join(mypath, "train_loss_list_regnet.npy"))
train_loss_list_hetio = np.load(join(mypath, "train_loss_list_hetio.npy"))
test_acc_list_fu˜ncoup = np.load(join(mypath, "test_acc_list_funcoup.npy"))
test_acc_list_genemania = np.load(join(mypath, "test_acc_list_genemania.npy"))
train_loss_list_stringdb = np.load(join(mypath, "train_loss_list_stringdb.npy"))
test_loss_list_stringdb = np.load(join(mypath, "test_loss_list_stringdb.npy"))
test_acc_list_hetio = np.load(join(mypath, "test_acc_list_hetio.npy"))
test_loss_list_genemania = np.load(join(mypath, "test_loss_list_genemania.npy"))
test_loss_list_hetio = np.load(join(mypath, "test_loss_list_hetio.npy"))
train_loss_list_funcoup = np.load(join(mypath, "train_loss_list_funcoup.npy"))
test_acc_list_stringdb = np.load(join(mypath, "test_acc_list_stringdb.npy"))
train_loss_list_genemania = np.load(join(mypath, "train_loss_list_genemania.npy"))
test_loss_list_funcoup = np.load(join(mypath, "test_loss_list_funcoup.npy"))

# %%
plt.figure(figsize=(20,10))
# plt.ylim(0, 2)
plt.plot(train_loss_list_regnet[:, 0], train_loss_list_regnet[:, 1], label="regnet")
plt.plot(train_loss_list_humannet[:, 0], train_loss_list_humannet[:, 1], label="humannet")
plt.plot(train_loss_list_hetio[:, 0], train_loss_list_hetio[:, 1], label="hetio")
plt.plot(train_loss_list_funcoup[:, 0], train_loss_list_funcoup[:, 1], label="funcoup")
plt.plot(train_loss_list_stringdb[:, 0], train_loss_list_stringdb[:, 1], label="stringdb")
plt.plot(train_loss_list_genemania[:, 0], train_loss_list_genemania[:, 1], label="genemania")
plt.legend()
plt.title("train")
plt.show()

# %%
plt.figure(figsize=(20,10))
# plt.ylim(0, 2)
plt.plot(test_loss_list_regnet[:, 0], test_loss_list_regnet[:, 1], label="regnet")
plt.plot(test_loss_list_humannet[:, 0], test_loss_list_humannet[:, 1], label="humannet")
plt.plot(test_loss_list_hetio[:, 0], test_loss_list_hetio[:, 1], label="hetio")
plt.plot(test_loss_list_funcoup[:, 0], test_loss_list_funcoup[:, 1], label="funcoup")
plt.plot(test_loss_list_stringdb[:, 0], test_loss_list_stringdb[:, 1], label="stringdb")
plt.plot(test_loss_list_genemania[:, 0], test_loss_list_genemania[:, 1], label="genemania")
plt.legend()
plt.title("test loss")
plt.show()

# %%
plt.figure(figsize=(20,10))
# plt.ylim(0, 1)
# plt.plot(test_acc_list_regnet[:, 0], test_acc_list_regnet[:, 1], label="regnet")
# plt.plot(test_acc_list_humannet[:, 0], test_acc_list_humannet[:, 1], label="humannet")
# plt.plot(test_acc_list_hetio[:, 0], test_acc_list_hetio[:, 1], label="hetio")
# plt.plot(test_acc_list_funcoup[:, 0], test_acc_list_funcoup[:, 1], label="funcoup")
plt.plot(test_acc_list_stringdb[:, 0], test_acc_list_stringdb[:, 1], label="stringdb")
# plt.plot(test_acc_list_genemania[:, 0], test_acc_list_genemania[:, 1], label="genemania")
plt.legend()
plt.title("test acc")
plt.show()

# %%
test_acc_list_regnet
# Out:
# array([[ 28.        ,   0.40990991],
#        [ 56.        ,   0.40990991],
#        [ 84.        ,   0.40990991],
#        [112.        ,   0.40990991],
#        [140.        ,   0.40990991],
#        [168.        ,   0.40990991],
#        [196.        ,   0.40990991],
#        [224.        ,   0.40990991],
#        [252.        ,   0.40990991],
#        [280.        ,   0.40990991]])
