# %%
import sys

import meta_dataloader.TCGA

import models.mlp, models.gcn
import numpy as np
import data.gene_graphs
import collections
import sklearn.metrics
import sklearn.model_selection
import random
from collections import OrderedDict
import pandas as pd
from torch.optim import Optimizer
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from torch import Tensor
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tasks = meta_dataloader.TCGA.TCGAMeta(download=True, 
                                      min_samples_per_class=10)
# Out:
# Downloading or checking for TCGA_HiSeqV2 using Academic Torrents
# Torrent name: HiSeqV2.gz, Size: 513.04MB

# %%
for taskid in sorted(tasks.task_ids):
    print(taskid)
# Out:
# ('Expression_Subtype', 'LUAD')
# ('Expression_Subtype', 'LUNG')
# ('GeneExp_Subtype', 'GBM')
# ('Metastasis_nature2012', 'BRCA')
# ('Node_nature2012', 'BRCA')
# ('PAM50Call_RNAseq', 'BRCA')
# ('_EVENT', 'ACC')
# ('_EVENT', 'BLCA')
# ('_EVENT', 'BRCA')
# ('_EVENT', 'CESC')
# ('_EVENT', 'CHOL')
# ('_EVENT', 'COAD')
# ('_EVENT', 'COADREAD')
# ('_EVENT', 'ESCA')
# ('_EVENT', 'GBM')
# ('_EVENT', 'GBMLGG')
# ('_EVENT', 'HNSC')
# ('_EVENT', 'KICH')
# ('_EVENT', 'KIRP')
# ('_EVENT', 'LAML')
# ('_EVENT', 'LGG')
# ('_EVENT', 'LIHC')
# ('_EVENT', 'LUAD')
# ('_EVENT', 'LUNG')
# ('_EVENT', 'LUSC')
# ('_EVENT', 'MESO')
# ('_EVENT', 'OV')
# ('_EVENT', 'PAAD')
# ('_EVENT', 'READ')
# ('_EVENT', 'SARC')
# ('_EVENT', 'SKCM')
# ('_EVENT', 'STAD')
# ('_EVENT', 'THCA')
# ('_EVENT', 'UCEC')
# ('_EVENT', 'UCS')
# ('_EVENT', 'UVM')
# ('_PANCAN_DNAMethyl_BLCA', 'BLCA')
# ('_PANCAN_DNAMethyl_BRCA', 'BRCA')
# ('_PANCAN_DNAMethyl_HNSC', 'HNSC')
# ('_PANCAN_DNAMethyl_LUAD', 'LUAD')
# ('_PANCAN_DNAMethyl_LUSC', 'LUSC')
# ('_PANCAN_mirna_BLCA', 'BLCA')
# ('_PANCAN_mirna_BRCA', 'BRCA')
# ('_PANCAN_mirna_HNSC', 'HNSC')
# ('_PANCAN_mirna_LAML', 'LAML')
# ('_PANCAN_mirna_LUAD', 'LUAD')
# ('_PANCAN_mirna_LUSC', 'LUSC')
# ('_PANCAN_mirna_OV', 'OV')
# ('acute_myeloid_leukemia_calgb_cytogenetics_risk_category', 'LAML')
# ('adjacent_hepatic_tissue_inflammation_extent_type', 'LIHC')
# ('alcohol_history_documented', 'ESCA')
# ('alcohol_history_documented', 'HNSC')
# ('alcohol_history_documented', 'PAAD')
# ('anatomic_neoplasm_subdivision', 'OV')
# ('anatomic_neoplasm_subdivision', 'PAAD')
# ('animal_insect_allergy_history', 'GBMLGG')
# ('animal_insect_allergy_history', 'LGG')
# ('antireflux_treatment', 'STAD')
# ('asthma_history', 'GBMLGG')
# ('asthma_history', 'LGG')
# ('atypical_mitotic_figures', 'ACC')
# ('barretts_esophagus', 'STAD')
# ('biochemical_recurrence', 'PRAD')
# ('birth_control_pill_history_usage_category', 'CESC')
# ('birth_control_pill_history_usage_category', 'UCEC')
# ('clinical_M', 'ACC')
# ('clinical_M', 'KICH')
# ('clinical_M', 'KIRP')
# ('clinical_stage', 'KIRP')
# ('colon_polyps_present', 'COAD')
# ('colon_polyps_present', 'COADREAD')
# ('colon_polyps_present', 'READ')
# ('diabetes', 'UCEC')
# ('family_history_of_cancer', 'GBMLGG')
# ('family_history_of_cancer', 'LGG')
# ('family_history_of_cancer', 'PAAD')
# ('family_history_of_primary_brain_tumor', 'GBMLGG')
# ('family_history_of_primary_brain_tumor', 'LGG')
# ('family_history_of_stomach_cancer', 'STAD')
# ('family_history_other_cancer', 'TGCT')
# ('gender', 'ACC')
# ('gender', 'BLCA')
# ('gender', 'BRCA')
# ('gender', 'CHOL')
# ('gender', 'COAD')
# ('gender', 'COADREAD')
# ('gender', 'DLBC')
# ('gender', 'ESCA')
# ('gender', 'GBM')
# ('gender', 'GBMLGG')
# ('gender', 'HNSC')
# ('gender', 'KICH')
# ('gender', 'KIRP')
# ('gender', 'LAML')
# ('gender', 'LGG')
# ('gender', 'LIHC')
# ('gender', 'LUAD')
# ('gender', 'LUNG')
# ('gender', 'LUSC')
# ('gender', 'MESO')
# ('gender', 'PAAD')
# ('gender', 'PCPG')
# ('gender', 'READ')
# ('gender', 'SARC')
# ('gender', 'SKCM')
# ('gender', 'STAD')
# ('gender', 'THCA')
# ('gender', 'THYM')
# ('gender', 'UVM')
# ('histological_type', 'ESCA')
# ('histological_type', 'LGG')
# ('histological_type', 'PCPG')
# ('histological_type', 'PRAD')
# ('histological_type', 'UCEC')
# ('histological_type', 'UCS')
# ('histological_type', 'UVM')
# ('hypertension', 'UCEC')
# ('hypertension', 'UCS')
# ('icd_10', 'TGCT')
# ('ldh1_mutation_found', 'GBMLGG')
# ('ldh1_mutation_found', 'LGG')
# ('lymphatic_invasion', 'COAD')
# ('lymphatic_invasion', 'COADREAD')
# ('lymphatic_invasion', 'OV')
# ('lymphatic_invasion', 'READ')
# ('lymphovascular_invasion_present', 'BLCA')
# ('lymphovascular_invasion_present', 'HNSC')
# ('lymphovascular_invasion_present', 'TGCT')
# ('menopause_status', 'BRCA')
# ('mental_status_changes', 'GBMLGG')
# ('mental_status_changes', 'LGG')
# ('metastatic_breast_carcinoma_estrogen_receptor_status', 'BRCA')
# ('metastatic_breast_carcinoma_progesterone_receptor_status', 'BRCA')
# ('metastatic_diagnosis', 'SARC')
# ('necrosis', 'ACC')
# ('oct_embedded', 'ACC')
# ('oct_embedded', 'BLCA')
# ('oct_embedded', 'BRCA')
# ('oct_embedded', 'CESC')
# ('oct_embedded', 'ESCA')
# ('oct_embedded', 'GBMLGG')
# ('oct_embedded', 'HNSC')
# ('oct_embedded', 'KIRP')
# ('oct_embedded', 'LGG')
# ('oct_embedded', 'LIHC')
# ('oct_embedded', 'LUAD')
# ('oct_embedded', 'LUNG')
# ('oct_embedded', 'LUSC')
# ('oct_embedded', 'MESO')
# ('oct_embedded', 'PAAD')
# ('oct_embedded', 'PCPG')
# ('oct_embedded', 'PRAD')
# ('oct_embedded', 'SARC')
# ('oct_embedded', 'SKCM')
# ('oct_embedded', 'STAD')
# ('oct_embedded', 'TGCT')
# ('oct_embedded', 'THCA')
# ('oct_embedded', 'THYM')
# ('oct_embedded', 'UCEC')
# ('oct_embedded', 'UCS')
# ('pregnancies', 'UCEC')
# ('synchronous_colon_cancer_present', 'COAD')
# ('synchronous_colon_cancer_present', 'COADREAD')
# ('tumor_tissue_site', 'COADREAD')
# ('tumor_tissue_site', 'GBMLGG')
# ('tumor_tissue_site', 'PCPG')
# ('tumor_tissue_site', 'THYM')
# ('venous_invasion', 'COAD')
# ('venous_invasion', 'COADREAD')
# ('venous_invasion', 'OV')
# ('venous_invasion', 'READ')
# ('weiss_venous_invasion', 'ACC')
# ('white_cell_count_result', 'KICH')
# ('white_cell_count_result', 'KIRP')

# %%
def load_sets(task, valid=False):
     
    X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(task._samples, 
                                                                                task._labels, 
                                                                                stratify=task._labels,
                                                                                train_size=50,
                                                                                test_size=100,
                                                                                shuffle=True,
                                                                                random_state=0
                                                                                 )
    
    train_set = TensorDataset( Tensor(X_train), Tensor(y_train))
    test_set = TensorDataset( Tensor(X_test), Tensor(y_test))

    if valid:
        X_test, X_valid, y_test, y_valid = sklearn.model_selection.train_test_split(X_test, 
                                                                                y_test, 
                                                                                stratify=y_test,
                                                                                train_size=50,
                                                                                test_size=50,
                                                                                shuffle=True,
                                                                                random_state=0
                                                                               )
        valid_set = TensorDataset( Tensor(X_valid), Tensor(y_valid))
        return train_set, valid_set, test_set
    
    return train_set, test_set

# %%
def train(model, dataset, task_id, stop_early=False):
    train_loss = []
    criterion = model.criterion
    if type(model).__name__ == "LogisticRegression":
        optimizer = torch.optim.LBFGS(model.parameters(), lr=1)
    else:
        optimizer = torch.optim.Adam(model.parameters(), lr=model.learning_rate, weight_decay= model.weight_decay)
     
    if stop_early:
        print("")
    else:
        train_set = dataset
        valid_set = None
 
    for i in range(model.epochs):
        for batch, labels in torch.utils.data.DataLoader(train_set, batch_size=model.batch_size, shuffle=True):
            labels = torch.autograd.Variable(labels.long())
            
            def closure():
                # Forward + Backward + Optimize
                optimizer.zero_grad()
                out = model(batch)
                loss = criterion(out, labels)
                loss.backward()
                return loss
            
            intermediate = optimizer.step(closure)
            loss = intermediate.item()
            train_loss.append(loss)

    return model, loss

# %%
def test(model, test_set):
    # Test the Model
    batch, labels = next(iter(torch.utils.data.DataLoader(test_set, batch_size=len(test_set), shuffle=False)))
    model.eval()
    outputs = model(batch)
    _, predicted = torch.max(outputs.data, 1)

    predicted = predicted.numpy()
    labels = labels.numpy()
    accuracy = (predicted == labels).mean()*100.
    return accuracy

# %%
class MultiLayerPerceptron(torch.nn.Module):
    def __init__(self, seed, input_size, num_classes, num_layers, channels, learning_rate, batch_size, epochs, patience, weight_decay):
        super(MultiLayerPerceptron, self).__init__()
        self.input_size = input_size
        self.learning_rate = learning_rate
        self.batch_size = batch_size
        self.epochs = epochs
        self.patience = patience
        self.weight_decay = weight_decay
        self.num_layers = num_layers
        self.channels = channels
        self.output_size = num_classes
        random.seed(seed)
        torch.manual_seed(seed)
        
        nodes = []
        nodes += channels
        architecture = OrderedDict()
        for i in range(self.num_layers):
            architecture['fc' + str(i)] = nn.Linear(input_size, nodes[i])
            architecture['relu' + str(i)] = torch.nn.ReLU()
            input_size = nodes[i]

        self.features = nn.Sequential(architecture)

        self.classifier = nn.Linear(input_size, num_classes)
    
    @property
    def criterion(self):
        criterion = F.cross_entropy
        return criterion
    
    @property
    def optimizer(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=self.learning_rate, weight_decay=self.weight_decay)
        return optimizer

    def forward(self, x):
        x = x.view(-1, self.input_size)
        features = self.features(x)
        logits = self.classifier(features)
        return logits

# %%
tasks_opt = sorted(random.sample(tasks.task_ids,k=25)) #tasks for hyperparameter tunning
print (tasks_opt)
# Out:
# [('PAM50Call_RNAseq', 'BRCA'), ('_EVENT', 'CHOL'), ('_EVENT', 'ESCA'), ('_EVENT', 'GBMLGG'), ('_EVENT', 'LAML'), ('_EVENT', 'LUSC'), ('_EVENT', 'UCEC'), ('_PANCAN_DNAMethyl_LUSC', 'LUSC'), ('alcohol_history_documented', 'HNSC'), ('biochemical_recurrence', 'PRAD'), ('clinical_M', 'ACC'), ('clinical_stage', 'KIRP'), ('colon_polyps_present', 'COADREAD'), ('diabetes', 'UCEC'), ('family_history_of_cancer', 'LGG'), ('gender', 'LIHC'), ('gender', 'STAD'), ('lymphovascular_invasion_present', 'HNSC'), ('oct_embedded', 'ACC'), ('oct_embedded', 'CESC'), ('oct_embedded', 'LUAD'), ('oct_embedded', 'MESO'), ('oct_embedded', 'STAD'), ('oct_embedded', 'THCA'), ('tumor_tissue_site', 'PCPG')]

# %% [markdown]
# # Number of Hidden Layers and Channels Optimization

# %%
lr = 0.001
weight_decay = 0.00005
batch_size = 32
epochs=100
patience = 10

# %%
num_layer= 1
channels1 = [[512], [256], [128], [64], [32]] # best :  [128] :  68.07407407407408
channel1_res = []
for channel in channels1:
    task_res = []
    for taskid in tasks_opt[:10]:
        task = meta_dataloader.TCGA.TCGATask(taskid)
        input_size = task._samples.shape[1]
        num_classes = len(collections.Counter(task._labels))
        try:
            train_set, valid_set, test_set = load_sets(task, valid=True)
            seed_res=[]
            for seed in range(0,3):
                MLP_model = MultiLayerPerceptron(seed, input_size, num_classes, num_layer, channel, lr, batch_size, epochs, patience, weight_decay)
                trained_model, train_loss = train(MLP_model, train_set, task.id, False)
                mlp_result = test(trained_model, valid_set)
                print('task {} ==> {} seed {}' .format(taskid, mlp_result, seed))
                seed_res.append(mlp_result)
            task_res.append(np.mean(seed_res))
            print("Average task performance for channel {}: {}" .format(channel, task_res))
        except:
            print("Not enough number of samples")
        
    channel1_res.append(np.mean(task_res))
print("Channel Average Performace: {}" .format(channel1_res))
best_channel_1 = channels1[channel1_res.index(max(channel1_res))]
print("The most optimal number of nodes for 1 number of layers architecture: {}" .format(best_channel_1))
# Out:
# task ('PAM50Call_RNAseq', 'BRCA') ==> 64.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 72.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 2
# Average task performance for channel [512]: [70.66666666666667]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 54.0 seed 0
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 1
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 2
# Average task performance for channel [512]: [70.66666666666667, 55.333333333333336]
# task ('_EVENT', 'GBMLGG') ==> 72.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 66.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 2
# Average task performance for channel [512]: [70.66666666666667, 55.333333333333336, 69.33333333333333]
# task ('_EVENT', 'LAML') ==> 50.0 seed 0
# task ('_EVENT', 'LAML') ==> 54.0 seed 1
# task ('_EVENT', 'LAML') ==> 54.0 seed 2
# Average task performance for channel [512]: [70.66666666666667, 55.333333333333336, 69.33333333333333, 52.666666666666664]
# task ('_EVENT', 'LUSC') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'LUSC') ==> 62.0 seed 1
# task ('_EVENT', 'LUSC') ==> 60.0 seed 2
# Average task performance for channel [512]: [70.66666666666667, 55.333333333333336, 69.33333333333333, 52.666666666666664, 59.333333333333336]
# task ('_EVENT', 'UCEC') ==> 78.0 seed 0
# task ('_EVENT', 'UCEC') ==> 80.0 seed 1
# task ('_EVENT', 'UCEC') ==> 80.0 seed 2
# Average task performance for channel [512]: [70.66666666666667, 55.333333333333336, 69.33333333333333, 52.666666666666664, 59.333333333333336, 79.33333333333333]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 68.0 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 62.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 60.0 seed 2
# Average task performance for channel [512]: [70.66666666666667, 55.333333333333336, 69.33333333333333, 52.666666666666664, 59.333333333333336, 79.33333333333333, 63.333333333333336]
# task ('alcohol_history_documented', 'HNSC') ==> 74.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 72.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 2
# Average task performance for channel [512]: [70.66666666666667, 55.333333333333336, 69.33333333333333, 52.666666666666664, 59.333333333333336, 79.33333333333333, 63.333333333333336, 71.33333333333333]
# task ('biochemical_recurrence', 'PRAD') ==> 86.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 86.0 seed 2
# Average task performance for channel [512]: [70.66666666666667, 55.333333333333336, 69.33333333333333, 52.666666666666664, 59.333333333333336, 79.33333333333333, 63.333333333333336, 71.33333333333333, 86.66666666666667]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 74.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 74.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 2
# Average task performance for channel [256]: [74.66666666666667]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 54.0 seed 0
# task ('_EVENT', 'ESCA') ==> 54.0 seed 1
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 2
# Average task performance for channel [256]: [74.66666666666667, 54.666666666666664]
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 2
# Average task performance for channel [256]: [74.66666666666667, 54.666666666666664, 69.33333333333333]
# task ('_EVENT', 'LAML') ==> 52.0 seed 0
# task ('_EVENT', 'LAML') ==> 52.0 seed 1
# task ('_EVENT', 'LAML') ==> 54.0 seed 2
# Average task performance for channel [256]: [74.66666666666667, 54.666666666666664, 69.33333333333333, 52.666666666666664]
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 0
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 2
# Average task performance for channel [256]: [74.66666666666667, 54.666666666666664, 69.33333333333333, 52.666666666666664, 57.99999999999999]
# task ('_EVENT', 'UCEC') ==> 80.0 seed 0
# task ('_EVENT', 'UCEC') ==> 80.0 seed 1
# task ('_EVENT', 'UCEC') ==> 80.0 seed 2
# Average task performance for channel [256]: [74.66666666666667, 54.666666666666664, 69.33333333333333, 52.666666666666664, 57.99999999999999, 80.0]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 57.99999999999999 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 60.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 64.0 seed 2
# Average task performance for channel [256]: [74.66666666666667, 54.666666666666664, 69.33333333333333, 52.666666666666664, 57.99999999999999, 80.0, 60.666666666666664]
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 72.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 2
# Average task performance for channel [256]: [74.66666666666667, 54.666666666666664, 69.33333333333333, 52.666666666666664, 57.99999999999999, 80.0, 60.666666666666664, 70.66666666666667]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 84.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 82.0 seed 2
# Average task performance for channel [256]: [74.66666666666667, 54.666666666666664, 69.33333333333333, 52.666666666666664, 57.99999999999999, 80.0, 60.666666666666664, 70.66666666666667, 84.66666666666667]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 66.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 80.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 2
# Average task performance for channel [128]: [74.0]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 1
# task ('_EVENT', 'ESCA') ==> 54.0 seed 2
# Average task performance for channel [128]: [74.0, 55.333333333333336]
# task ('_EVENT', 'GBMLGG') ==> 66.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 2
# Average task performance for channel [128]: [74.0, 55.333333333333336, 68.66666666666667]
# task ('_EVENT', 'LAML') ==> 60.0 seed 0
# task ('_EVENT', 'LAML') ==> 54.0 seed 1
# task ('_EVENT', 'LAML') ==> 62.0 seed 2
# Average task performance for channel [128]: [74.0, 55.333333333333336, 68.66666666666667, 58.666666666666664]
# task ('_EVENT', 'LUSC') ==> 60.0 seed 0
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'LUSC') ==> 56.00000000000001 seed 2
# Average task performance for channel [128]: [74.0, 55.333333333333336, 68.66666666666667, 58.666666666666664, 58.0]
# task ('_EVENT', 'UCEC') ==> 80.0 seed 0
# task ('_EVENT', 'UCEC') ==> 80.0 seed 1
# task ('_EVENT', 'UCEC') ==> 80.0 seed 2
# Average task performance for channel [128]: [74.0, 55.333333333333336, 68.66666666666667, 58.666666666666664, 58.0, 80.0]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 60.0 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 62.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 57.99999999999999 seed 2
# Average task performance for channel [128]: [74.0, 55.333333333333336, 68.66666666666667, 58.666666666666664, 58.0, 80.0, 60.0]
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 74.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 2
# Average task performance for channel [128]: [74.0, 55.333333333333336, 68.66666666666667, 58.666666666666664, 58.0, 80.0, 60.0, 71.33333333333333]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 86.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 86.0 seed 2
# Average task performance for channel [128]: [74.0, 55.333333333333336, 68.66666666666667, 58.666666666666664, 58.0, 80.0, 60.0, 71.33333333333333, 86.66666666666667]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 68.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 70.0 seed 2
# Average task performance for channel [64]: [72.0]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 1
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 2
# Average task performance for channel [64]: [72.0, 56.00000000000001]
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 2
# Average task performance for channel [64]: [72.0, 56.00000000000001, 69.33333333333333]
# task ('_EVENT', 'LAML') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'LAML') ==> 54.0 seed 1
# task ('_EVENT', 'LAML') ==> 56.00000000000001 seed 2
# Average task performance for channel [64]: [72.0, 56.00000000000001, 69.33333333333333, 55.333333333333336]
# task ('_EVENT', 'LUSC') ==> 62.0 seed 0
# task ('_EVENT', 'LUSC') ==> 60.0 seed 1
# task ('_EVENT', 'LUSC') ==> 54.0 seed 2
# Average task performance for channel [64]: [72.0, 56.00000000000001, 69.33333333333333, 55.333333333333336, 58.666666666666664]
# task ('_EVENT', 'UCEC') ==> 72.0 seed 0
# task ('_EVENT', 'UCEC') ==> 80.0 seed 1
# task ('_EVENT', 'UCEC') ==> 82.0 seed 2
# Average task performance for channel [64]: [72.0, 56.00000000000001, 69.33333333333333, 55.333333333333336, 58.666666666666664, 78.0]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 66.0 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 70.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 56.00000000000001 seed 2
# Average task performance for channel [64]: [72.0, 56.00000000000001, 69.33333333333333, 55.333333333333336, 58.666666666666664, 78.0, 64.0]
# task ('alcohol_history_documented', 'HNSC') ==> 72.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 2
# Average task performance for channel [64]: [72.0, 56.00000000000001, 69.33333333333333, 55.333333333333336, 58.666666666666664, 78.0, 64.0, 69.33333333333333]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 86.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 86.0 seed 2
# Average task performance for channel [64]: [72.0, 56.00000000000001, 69.33333333333333, 55.333333333333336, 58.666666666666664, 78.0, 64.0, 69.33333333333333, 86.66666666666667]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 80.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 70.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 60.0 seed 2
# Average task performance for channel [32]: [70.0]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'ESCA') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 2
# Average task performance for channel [32]: [70.0, 56.666666666666664]
# task ('_EVENT', 'GBMLGG') ==> 62.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 2
# Average task performance for channel [32]: [70.0, 56.666666666666664, 67.33333333333333]
# task ('_EVENT', 'LAML') ==> 64.0 seed 0
# task ('_EVENT', 'LAML') ==> 56.00000000000001 seed 1
# task ('_EVENT', 'LAML') ==> 57.99999999999999 seed 2
# Average task performance for channel [32]: [70.0, 56.666666666666664, 67.33333333333333, 59.333333333333336]
# task ('_EVENT', 'LUSC') ==> 60.0 seed 0
# task ('_EVENT', 'LUSC') ==> 54.0 seed 1
# task ('_EVENT', 'LUSC') ==> 56.00000000000001 seed 2
# Average task performance for channel [32]: [70.0, 56.666666666666664, 67.33333333333333, 59.333333333333336, 56.666666666666664]
# task ('_EVENT', 'UCEC') ==> 80.0 seed 0
# task ('_EVENT', 'UCEC') ==> 82.0 seed 1
# task ('_EVENT', 'UCEC') ==> 82.0 seed 2
# Average task performance for channel [32]: [70.0, 56.666666666666664, 67.33333333333333, 59.333333333333336, 56.666666666666664, 81.33333333333333]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 38.0 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 30.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 60.0 seed 2
# Average task performance for channel [32]: [70.0, 56.666666666666664, 67.33333333333333, 59.333333333333336, 56.666666666666664, 81.33333333333333, 42.666666666666664]
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 66.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 72.0 seed 2
# Average task performance for channel [32]: [70.0, 56.666666666666664, 67.33333333333333, 59.333333333333336, 56.666666666666664, 81.33333333333333, 42.666666666666664, 68.66666666666667]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 84.0 seed 2
# Average task performance for channel [32]: [70.0, 56.666666666666664, 67.33333333333333, 59.333333333333336, 56.666666666666664, 81.33333333333333, 42.666666666666664, 68.66666666666667, 86.66666666666667]
# Channel Average Performace: [67.55555555555554, 67.25925925925927, 68.07407407407408, 67.7037037037037, 65.48148148148147]
# The most optimal number of nodes for 1 number of layers architecture: [128]

# %%
num_layer= 2
channels2 = [[512,256], [256,128], [128,64]] # best: [128, 64] : 68.14814814814815
channel2_res = []
for channel in channels2:
    task_res = []
    for taskid in tasks_opt[:10]:
        task = meta_dataloader.TCGA.TCGATask(taskid)
        input_size = task._samples.shape[1]
        num_classes = len(collections.Counter(task._labels))
        try:
            train_set, valid_set, test_set = load_sets(task, valid=True)
            seed_res=[]
            for seed in range(0,3):
                MLP_model = MultiLayerPerceptron(seed, input_size, num_classes, num_layer, channel, lr, batch_size, epochs, patience, weight_decay)
                trained_model, train_loss = train(MLP_model, train_set, task.id, False)
                mlp_result = test(trained_model, valid_set)
                print('task {} ==> {} seed {}' .format(taskid, mlp_result, seed))
                seed_res.append(mlp_result)
            task_res.append(np.mean(seed_res))
            print("Average task performance for channel {}: {}" .format(channel, task_res))
        except:
            print("Not enough number of samples")
        
    channel2_res.append(np.mean(task_res))
print("Channel Average Performace: {}" .format(channel2_res))
best_channel_2 = channels2[channel2_res.index(max(channel2_res))]
print("The most optimal number of nodes for 2 number of layers architecture: {}" .format(best_channel_2))
# Out:
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 2
# Average task performance for channel [512, 256]: [77.33333333333333]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 1
# task ('_EVENT', 'ESCA') ==> 54.0 seed 2
# Average task performance for channel [512, 256]: [77.33333333333333, 55.333333333333336]
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 62.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 2
# Average task performance for channel [512, 256]: [77.33333333333333, 55.333333333333336, 66.0]
# task ('_EVENT', 'LAML') ==> 60.0 seed 0
# task ('_EVENT', 'LAML') ==> 56.00000000000001 seed 1
# task ('_EVENT', 'LAML') ==> 50.0 seed 2
# Average task performance for channel [512, 256]: [77.33333333333333, 55.333333333333336, 66.0, 55.333333333333336]
# task ('_EVENT', 'LUSC') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'LUSC') ==> 60.0 seed 1
# task ('_EVENT', 'LUSC') ==> 60.0 seed 2
# Average task performance for channel [512, 256]: [77.33333333333333, 55.333333333333336, 66.0, 55.333333333333336, 58.666666666666664]
# task ('_EVENT', 'UCEC') ==> 80.0 seed 0
# task ('_EVENT', 'UCEC') ==> 80.0 seed 1
# task ('_EVENT', 'UCEC') ==> 80.0 seed 2
# Average task performance for channel [512, 256]: [77.33333333333333, 55.333333333333336, 66.0, 55.333333333333336, 58.666666666666664, 80.0]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 57.99999999999999 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 60.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 66.0 seed 2
# Average task performance for channel [512, 256]: [77.33333333333333, 55.333333333333336, 66.0, 55.333333333333336, 58.666666666666664, 80.0, 61.333333333333336]
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 72.0 seed 2
# Average task performance for channel [512, 256]: [77.33333333333333, 55.333333333333336, 66.0, 55.333333333333336, 58.666666666666664, 80.0, 61.333333333333336, 70.0]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 86.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 2
# Average task performance for channel [512, 256]: [77.33333333333333, 55.333333333333336, 66.0, 55.333333333333336, 58.666666666666664, 80.0, 61.333333333333336, 70.0, 87.33333333333333]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 74.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 74.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 72.0 seed 2
# Average task performance for channel [256, 128]: [73.33333333333333]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'ESCA') ==> 54.0 seed 1
# task ('_EVENT', 'ESCA') ==> 54.0 seed 2
# Average task performance for channel [256, 128]: [73.33333333333333, 54.666666666666664]
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 2
# Average task performance for channel [256, 128]: [73.33333333333333, 54.666666666666664, 68.66666666666667]
# task ('_EVENT', 'LAML') ==> 48.0 seed 0
# task ('_EVENT', 'LAML') ==> 52.0 seed 1
# task ('_EVENT', 'LAML') ==> 56.00000000000001 seed 2
# Average task performance for channel [256, 128]: [73.33333333333333, 54.666666666666664, 68.66666666666667, 52.0]
# task ('_EVENT', 'LUSC') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'LUSC') ==> 62.0 seed 1
# task ('_EVENT', 'LUSC') ==> 64.0 seed 2
# Average task performance for channel [256, 128]: [73.33333333333333, 54.666666666666664, 68.66666666666667, 52.0, 60.666666666666664]
# task ('_EVENT', 'UCEC') ==> 80.0 seed 0
# task ('_EVENT', 'UCEC') ==> 80.0 seed 1
# task ('_EVENT', 'UCEC') ==> 80.0 seed 2
# Average task performance for channel [256, 128]: [73.33333333333333, 54.666666666666664, 68.66666666666667, 52.0, 60.666666666666664, 80.0]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 62.0 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 66.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 64.0 seed 2
# Average task performance for channel [256, 128]: [73.33333333333333, 54.666666666666664, 68.66666666666667, 52.0, 60.666666666666664, 80.0, 64.0]
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 2
# Average task performance for channel [256, 128]: [73.33333333333333, 54.666666666666664, 68.66666666666667, 52.0, 60.666666666666664, 80.0, 64.0, 69.33333333333333]
# task ('biochemical_recurrence', 'PRAD') ==> 86.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 86.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 2
# Average task performance for channel [256, 128]: [73.33333333333333, 54.666666666666664, 68.66666666666667, 52.0, 60.666666666666664, 80.0, 64.0, 69.33333333333333, 86.66666666666667]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 72.0 seed 2
# Average task performance for channel [128, 64]: [75.33333333333333]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 54.0 seed 0
# task ('_EVENT', 'ESCA') ==> 54.0 seed 1
# task ('_EVENT', 'ESCA') ==> 57.99999999999999 seed 2
# Average task performance for channel [128, 64]: [75.33333333333333, 55.333333333333336]
# task ('_EVENT', 'GBMLGG') ==> 62.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 2
# Average task performance for channel [128, 64]: [75.33333333333333, 55.333333333333336, 67.33333333333333]
# task ('_EVENT', 'LAML') ==> 54.0 seed 0
# task ('_EVENT', 'LAML') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'LAML') ==> 57.99999999999999 seed 2
# Average task performance for channel [128, 64]: [75.33333333333333, 55.333333333333336, 67.33333333333333, 56.666666666666664]
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 0
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'LUSC') ==> 60.0 seed 2
# Average task performance for channel [128, 64]: [75.33333333333333, 55.333333333333336, 67.33333333333333, 56.666666666666664, 58.666666666666664]
# task ('_EVENT', 'UCEC') ==> 82.0 seed 0
# task ('_EVENT', 'UCEC') ==> 80.0 seed 1
# task ('_EVENT', 'UCEC') ==> 80.0 seed 2
# Average task performance for channel [128, 64]: [75.33333333333333, 55.333333333333336, 67.33333333333333, 56.666666666666664, 58.666666666666664, 80.66666666666667]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 66.0 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 60.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 62.0 seed 2
# Average task performance for channel [128, 64]: [75.33333333333333, 55.333333333333336, 67.33333333333333, 56.666666666666664, 58.666666666666664, 80.66666666666667, 62.666666666666664]
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 2
# Average task performance for channel [128, 64]: [75.33333333333333, 55.333333333333336, 67.33333333333333, 56.666666666666664, 58.666666666666664, 80.66666666666667, 62.666666666666664, 68.66666666666667]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 2
# Average task performance for channel [128, 64]: [75.33333333333333, 55.333333333333336, 67.33333333333333, 56.666666666666664, 58.666666666666664, 80.66666666666667, 62.666666666666664, 68.66666666666667, 88.0]
# Channel Average Performace: [67.92592592592592, 67.70370370370371, 68.14814814814815]
# The most optimal number of nodes for 2 number of layers architecture: [128, 64]

# %%
num_layer= 3
channels3 = [[128,64,32],[256,128,64],[512,128,64],[256,128,32]] # Best : [128, 64, 32] : 68.24561403508771
channel3_res = []
for channel in channels3:
    task_res = []
    for taskid in tasks_opt:
        task = meta_dataloader.TCGA.TCGATask(taskid)
        input_size = task._samples.shape[1]
        num_classes = len(collections.Counter(task._labels))
        try:
            train_set, valid_set, test_set = load_sets(task, valid=True)
            seed_res=[]
            for seed in range(0,3):
                MLP_model = MultiLayerPerceptron(seed, input_size, num_classes, num_layer, channel, lr, batch_size, epochs, patience, weight_decay)
                trained_model, train_loss = train(MLP_model, train_set, task.id, False)
                mlp_result = test(trained_model, valid_set)
                print('task {} ==> {} seed {}' .format(taskid, mlp_result, seed))
                seed_res.append(mlp_result)
            task_res.append(np.mean(seed_res))
            print("Average task performance for channel {}: {}" .format(channel, task_res))
        except:
            print("Not enough number of samples")
        
    channel3_res.append(np.mean(task_res))
print("Channel Average Performace: {}" .format(channel3_res))
best_channel_3 = channels3[channel3_res.index(max(channel3_res))]
print("The most optimal number of nodes for 3 number of layers architecture: {}" .format(best_channel_3))
# Out:
# task ('PAM50Call_RNAseq', 'BRCA') ==> 74.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 80.0 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'ESCA') ==> 54.0 seed 1
# task ('_EVENT', 'ESCA') ==> 54.0 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667, 54.666666666666664]
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667, 54.666666666666664, 69.33333333333333]
# task ('_EVENT', 'LAML') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'LAML') ==> 60.0 seed 1
# task ('_EVENT', 'LAML') ==> 56.00000000000001 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667, 54.666666666666664, 69.33333333333333, 57.333333333333336]
# task ('_EVENT', 'LUSC') ==> 60.0 seed 0
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667, 54.666666666666664, 69.33333333333333, 57.333333333333336, 58.666666666666664]
# task ('_EVENT', 'UCEC') ==> 82.0 seed 0
# task ('_EVENT', 'UCEC') ==> 80.0 seed 1
# task ('_EVENT', 'UCEC') ==> 82.0 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667, 54.666666666666664, 69.33333333333333, 57.333333333333336, 58.666666666666664, 81.33333333333333]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 62.0 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 60.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 60.0 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667, 54.666666666666664, 69.33333333333333, 57.333333333333336, 58.666666666666664, 81.33333333333333, 60.666666666666664]
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667, 54.666666666666664, 69.33333333333333, 57.333333333333336, 58.666666666666664, 81.33333333333333, 60.666666666666664, 68.66666666666667]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 86.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667, 54.666666666666664, 69.33333333333333, 57.333333333333336, 58.666666666666664, 81.33333333333333, 60.666666666666664, 68.66666666666667, 87.33333333333333]
# Not enough number of samples
# task ('clinical_stage', 'KIRP') ==> 62.0 seed 0
# task ('clinical_stage', 'KIRP') ==> 60.0 seed 1
# task ('clinical_stage', 'KIRP') ==> 66.0 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667, 54.666666666666664, 69.33333333333333, 57.333333333333336, 58.666666666666664, 81.33333333333333, 60.666666666666664, 68.66666666666667, 87.33333333333333, 62.666666666666664]
# task ('colon_polyps_present', 'COADREAD') ==> 72.0 seed 0
# task ('colon_polyps_present', 'COADREAD') ==> 72.0 seed 1
# task ('colon_polyps_present', 'COADREAD') ==> 72.0 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667, 54.666666666666664, 69.33333333333333, 57.333333333333336, 58.666666666666664, 81.33333333333333, 60.666666666666664, 68.66666666666667, 87.33333333333333, 62.666666666666664, 72.0]
# Not enough number of samples
# task ('family_history_of_cancer', 'LGG') ==> 56.00000000000001 seed 0
# task ('family_history_of_cancer', 'LGG') ==> 57.99999999999999 seed 1
# task ('family_history_of_cancer', 'LGG') ==> 56.00000000000001 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667, 54.666666666666664, 69.33333333333333, 57.333333333333336, 58.666666666666664, 81.33333333333333, 60.666666666666664, 68.66666666666667, 87.33333333333333, 62.666666666666664, 72.0, 56.666666666666664]
# task ('gender', 'LIHC') ==> 84.0 seed 0
# task ('gender', 'LIHC') ==> 78.0 seed 1
# task ('gender', 'LIHC') ==> 84.0 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667, 54.666666666666664, 69.33333333333333, 57.333333333333336, 58.666666666666664, 81.33333333333333, 60.666666666666664, 68.66666666666667, 87.33333333333333, 62.666666666666664, 72.0, 56.666666666666664, 82.0]
# task ('gender', 'STAD') ==> 78.0 seed 0
# task ('gender', 'STAD') ==> 78.0 seed 1
# task ('gender', 'STAD') ==> 80.0 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667, 54.666666666666664, 69.33333333333333, 57.333333333333336, 58.666666666666664, 81.33333333333333, 60.666666666666664, 68.66666666666667, 87.33333333333333, 62.666666666666664, 72.0, 56.666666666666664, 82.0, 78.66666666666667]
# task ('lymphovascular_invasion_present', 'HNSC') ==> 64.0 seed 0
# task ('lymphovascular_invasion_present', 'HNSC') ==> 66.0 seed 1
# task ('lymphovascular_invasion_present', 'HNSC') ==> 66.0 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667, 54.666666666666664, 69.33333333333333, 57.333333333333336, 58.666666666666664, 81.33333333333333, 60.666666666666664, 68.66666666666667, 87.33333333333333, 62.666666666666664, 72.0, 56.666666666666664, 82.0, 78.66666666666667, 65.33333333333333]
# Not enough number of samples
# task ('oct_embedded', 'CESC') ==> 56.00000000000001 seed 0
# task ('oct_embedded', 'CESC') ==> 56.00000000000001 seed 1
# task ('oct_embedded', 'CESC') ==> 56.00000000000001 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667, 54.666666666666664, 69.33333333333333, 57.333333333333336, 58.666666666666664, 81.33333333333333, 60.666666666666664, 68.66666666666667, 87.33333333333333, 62.666666666666664, 72.0, 56.666666666666664, 82.0, 78.66666666666667, 65.33333333333333, 56.00000000000001]
# Not enough number of samples
# Not enough number of samples
# task ('oct_embedded', 'STAD') ==> 60.0 seed 0
# task ('oct_embedded', 'STAD') ==> 62.0 seed 1
# task ('oct_embedded', 'STAD') ==> 62.0 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667, 54.666666666666664, 69.33333333333333, 57.333333333333336, 58.666666666666664, 81.33333333333333, 60.666666666666664, 68.66666666666667, 87.33333333333333, 62.666666666666664, 72.0, 56.666666666666664, 82.0, 78.66666666666667, 65.33333333333333, 56.00000000000001, 61.333333333333336]
# task ('oct_embedded', 'THCA') ==> 54.0 seed 0
# task ('oct_embedded', 'THCA') ==> 46.0 seed 1
# task ('oct_embedded', 'THCA') ==> 66.0 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667, 54.666666666666664, 69.33333333333333, 57.333333333333336, 58.666666666666664, 81.33333333333333, 60.666666666666664, 68.66666666666667, 87.33333333333333, 62.666666666666664, 72.0, 56.666666666666664, 82.0, 78.66666666666667, 65.33333333333333, 56.00000000000001, 61.333333333333336, 55.333333333333336]
# task ('tumor_tissue_site', 'PCPG') ==> 92.0 seed 0
# task ('tumor_tissue_site', 'PCPG') ==> 92.0 seed 1
# task ('tumor_tissue_site', 'PCPG') ==> 92.0 seed 2
# Average task performance for channel [128, 64, 32]: [76.66666666666667, 54.666666666666664, 69.33333333333333, 57.333333333333336, 58.666666666666664, 81.33333333333333, 60.666666666666664, 68.66666666666667, 87.33333333333333, 62.666666666666664, 72.0, 56.666666666666664, 82.0, 78.66666666666667, 65.33333333333333, 56.00000000000001, 61.333333333333336, 55.333333333333336, 92.0]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 82.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 2
# Average task performance for channel [256, 128, 68]: [78.0]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 54.0 seed 0
# task ('_EVENT', 'ESCA') ==> 54.0 seed 1
# task ('_EVENT', 'ESCA') ==> 54.0 seed 2
# Average task performance for channel [256, 128, 68]: [78.0, 54.0]
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 2
# Average task performance for channel [256, 128, 68]: [78.0, 54.0, 68.66666666666667]
# task ('_EVENT', 'LAML') ==> 52.0 seed 0
# task ('_EVENT', 'LAML') ==> 56.00000000000001 seed 1
# task ('_EVENT', 'LAML') ==> 48.0 seed 2
# Average task performance for channel [256, 128, 68]: [78.0, 54.0, 68.66666666666667, 52.0]
# task ('_EVENT', 'LUSC') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'LUSC') ==> 62.0 seed 1
# task ('_EVENT', 'LUSC') ==> 60.0 seed 2
# Average task performance for channel [256, 128, 68]: [78.0, 54.0, 68.66666666666667, 52.0, 59.333333333333336]
# task ('_EVENT', 'UCEC') ==> 82.0 seed 0
# task ('_EVENT', 'UCEC') ==> 80.0 seed 1
# task ('_EVENT', 'UCEC') ==> 80.0 seed 2
# Average task performance for channel [256, 128, 68]: [78.0, 54.0, 68.66666666666667, 52.0, 59.333333333333336, 80.66666666666667]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 56.00000000000001 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 62.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 66.0 seed 2
# Average task performance for channel [256, 128, 68]: [78.0, 54.0, 68.66666666666667, 52.0, 59.333333333333336, 80.66666666666667, 61.333333333333336]
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 76.0 seed 2
# Average task performance for channel [256, 128, 68]: [78.0, 54.0, 68.66666666666667, 52.0, 59.333333333333336, 80.66666666666667, 61.333333333333336, 70.66666666666667]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 2
# Average task performance for channel [256, 128, 68]: [78.0, 54.0, 68.66666666666667, 52.0, 59.333333333333336, 80.66666666666667, 61.333333333333336, 70.66666666666667, 88.0]
# Not enough number of samples
# task ('clinical_stage', 'KIRP') ==> 62.0 seed 0
# task ('clinical_stage', 'KIRP') ==> 64.0 seed 1
# task ('clinical_stage', 'KIRP') ==> 66.0 seed 2
# Average task performance for channel [256, 128, 68]: [78.0, 54.0, 68.66666666666667, 52.0, 59.333333333333336, 80.66666666666667, 61.333333333333336, 70.66666666666667, 88.0, 64.0]
# task ('colon_polyps_present', 'COADREAD') ==> 72.0 seed 0
# task ('colon_polyps_present', 'COADREAD') ==> 57.99999999999999 seed 1
# task ('colon_polyps_present', 'COADREAD') ==> 70.0 seed 2
# Average task performance for channel [256, 128, 68]: [78.0, 54.0, 68.66666666666667, 52.0, 59.333333333333336, 80.66666666666667, 61.333333333333336, 70.66666666666667, 88.0, 64.0, 66.66666666666667]
# Not enough number of samples
# task ('family_history_of_cancer', 'LGG') ==> 42.0 seed 0
# task ('family_history_of_cancer', 'LGG') ==> 24.0 seed 1
# task ('family_history_of_cancer', 'LGG') ==> 40.0 seed 2
# Average task performance for channel [256, 128, 68]: [78.0, 54.0, 68.66666666666667, 52.0, 59.333333333333336, 80.66666666666667, 61.333333333333336, 70.66666666666667, 88.0, 64.0, 66.66666666666667, 35.333333333333336]
# task ('gender', 'LIHC') ==> 78.0 seed 0
# task ('gender', 'LIHC') ==> 78.0 seed 1
# task ('gender', 'LIHC') ==> 80.0 seed 2
# Average task performance for channel [256, 128, 68]: [78.0, 54.0, 68.66666666666667, 52.0, 59.333333333333336, 80.66666666666667, 61.333333333333336, 70.66666666666667, 88.0, 64.0, 66.66666666666667, 35.333333333333336, 78.66666666666667]
# task ('gender', 'STAD') ==> 78.0 seed 0
# task ('gender', 'STAD') ==> 78.0 seed 1
# task ('gender', 'STAD') ==> 78.0 seed 2
# Average task performance for channel [256, 128, 68]: [78.0, 54.0, 68.66666666666667, 52.0, 59.333333333333336, 80.66666666666667, 61.333333333333336, 70.66666666666667, 88.0, 64.0, 66.66666666666667, 35.333333333333336, 78.66666666666667, 78.0]
# task ('lymphovascular_invasion_present', 'HNSC') ==> 64.0 seed 0
# task ('lymphovascular_invasion_present', 'HNSC') ==> 64.0 seed 1
# task ('lymphovascular_invasion_present', 'HNSC') ==> 64.0 seed 2
# Average task performance for channel [256, 128, 68]: [78.0, 54.0, 68.66666666666667, 52.0, 59.333333333333336, 80.66666666666667, 61.333333333333336, 70.66666666666667, 88.0, 64.0, 66.66666666666667, 35.333333333333336, 78.66666666666667, 78.0, 64.0]
# Not enough number of samples
# task ('oct_embedded', 'CESC') ==> 56.00000000000001 seed 0
# task ('oct_embedded', 'CESC') ==> 56.00000000000001 seed 1
# task ('oct_embedded', 'CESC') ==> 56.00000000000001 seed 2
# Average task performance for channel [256, 128, 68]: [78.0, 54.0, 68.66666666666667, 52.0, 59.333333333333336, 80.66666666666667, 61.333333333333336, 70.66666666666667, 88.0, 64.0, 66.66666666666667, 35.333333333333336, 78.66666666666667, 78.0, 64.0, 56.00000000000001]
# Not enough number of samples
# Not enough number of samples
# task ('oct_embedded', 'STAD') ==> 62.0 seed 0
# task ('oct_embedded', 'STAD') ==> 60.0 seed 1
# task ('oct_embedded', 'STAD') ==> 62.0 seed 2
# Average task performance for channel [256, 128, 68]: [78.0, 54.0, 68.66666666666667, 52.0, 59.333333333333336, 80.66666666666667, 61.333333333333336, 70.66666666666667, 88.0, 64.0, 66.66666666666667, 35.333333333333336, 78.66666666666667, 78.0, 64.0, 56.00000000000001, 61.333333333333336]
# task ('oct_embedded', 'THCA') ==> 52.0 seed 0
# task ('oct_embedded', 'THCA') ==> 66.0 seed 1
# task ('oct_embedded', 'THCA') ==> 68.0 seed 2
# Average task performance for channel [256, 128, 68]: [78.0, 54.0, 68.66666666666667, 52.0, 59.333333333333336, 80.66666666666667, 61.333333333333336, 70.66666666666667, 88.0, 64.0, 66.66666666666667, 35.333333333333336, 78.66666666666667, 78.0, 64.0, 56.00000000000001, 61.333333333333336, 62.0]
# task ('tumor_tissue_site', 'PCPG') ==> 92.0 seed 0
# task ('tumor_tissue_site', 'PCPG') ==> 92.0 seed 1
# task ('tumor_tissue_site', 'PCPG') ==> 92.0 seed 2
# Average task performance for channel [256, 128, 68]: [78.0, 54.0, 68.66666666666667, 52.0, 59.333333333333336, 80.66666666666667, 61.333333333333336, 70.66666666666667, 88.0, 64.0, 66.66666666666667, 35.333333333333336, 78.66666666666667, 78.0, 64.0, 56.00000000000001, 61.333333333333336, 62.0, 92.0]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 82.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 2
# Average task performance for channel [512, 128, 64]: [78.0]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'ESCA') ==> 54.0 seed 1
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 2
# Average task performance for channel [512, 128, 64]: [78.0, 55.333333333333336]
# task ('_EVENT', 'GBMLGG') ==> 72.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 72.0 seed 2
# Average task performance for channel [512, 128, 64]: [78.0, 55.333333333333336, 71.33333333333333]
# task ('_EVENT', 'LAML') ==> 52.0 seed 0
# task ('_EVENT', 'LAML') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'LAML') ==> 48.0 seed 2
# Average task performance for channel [512, 128, 64]: [78.0, 55.333333333333336, 71.33333333333333, 52.666666666666664]
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 0
# task ('_EVENT', 'LUSC') ==> 64.0 seed 1
# task ('_EVENT', 'LUSC') ==> 60.0 seed 2
# Average task performance for channel [512, 128, 64]: [78.0, 55.333333333333336, 71.33333333333333, 52.666666666666664, 60.666666666666664]
# task ('_EVENT', 'UCEC') ==> 80.0 seed 0
# task ('_EVENT', 'UCEC') ==> 80.0 seed 1
# task ('_EVENT', 'UCEC') ==> 82.0 seed 2
# Average task performance for channel [512, 128, 64]: [78.0, 55.333333333333336, 71.33333333333333, 52.666666666666664, 60.666666666666664, 80.66666666666667]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 57.99999999999999 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 68.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 66.0 seed 2
# Average task performance for channel [512, 128, 64]: [78.0, 55.333333333333336, 71.33333333333333, 52.666666666666664, 60.666666666666664, 80.66666666666667, 64.0]
# task ('alcohol_history_documented', 'HNSC') ==> 72.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 2
# Average task performance for channel [512, 128, 64]: [78.0, 55.333333333333336, 71.33333333333333, 52.666666666666664, 60.666666666666664, 80.66666666666667, 64.0, 69.33333333333333]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 2
# Average task performance for channel [512, 128, 64]: [78.0, 55.333333333333336, 71.33333333333333, 52.666666666666664, 60.666666666666664, 80.66666666666667, 64.0, 69.33333333333333, 88.0]
# Not enough number of samples
# task ('clinical_stage', 'KIRP') ==> 60.0 seed 0
# task ('clinical_stage', 'KIRP') ==> 60.0 seed 1
# task ('clinical_stage', 'KIRP') ==> 66.0 seed 2
# Average task performance for channel [512, 128, 64]: [78.0, 55.333333333333336, 71.33333333333333, 52.666666666666664, 60.666666666666664, 80.66666666666667, 64.0, 69.33333333333333, 88.0, 62.0]
# task ('colon_polyps_present', 'COADREAD') ==> 72.0 seed 0
# task ('colon_polyps_present', 'COADREAD') ==> 72.0 seed 1
# task ('colon_polyps_present', 'COADREAD') ==> 66.0 seed 2
# Average task performance for channel [512, 128, 64]: [78.0, 55.333333333333336, 71.33333333333333, 52.666666666666664, 60.666666666666664, 80.66666666666667, 64.0, 69.33333333333333, 88.0, 62.0, 70.0]
# Not enough number of samples
# task ('family_history_of_cancer', 'LGG') ==> 32.0 seed 0
# task ('family_history_of_cancer', 'LGG') ==> 56.00000000000001 seed 1
# task ('family_history_of_cancer', 'LGG') ==> 57.99999999999999 seed 2
# Average task performance for channel [512, 128, 64]: [78.0, 55.333333333333336, 71.33333333333333, 52.666666666666664, 60.666666666666664, 80.66666666666667, 64.0, 69.33333333333333, 88.0, 62.0, 70.0, 48.666666666666664]
# task ('gender', 'LIHC') ==> 78.0 seed 0
# task ('gender', 'LIHC') ==> 78.0 seed 1
# task ('gender', 'LIHC') ==> 84.0 seed 2
# Average task performance for channel [512, 128, 64]: [78.0, 55.333333333333336, 71.33333333333333, 52.666666666666664, 60.666666666666664, 80.66666666666667, 64.0, 69.33333333333333, 88.0, 62.0, 70.0, 48.666666666666664, 80.0]
# task ('gender', 'STAD') ==> 78.0 seed 0
# task ('gender', 'STAD') ==> 80.0 seed 1
# task ('gender', 'STAD') ==> 78.0 seed 2
# Average task performance for channel [512, 128, 64]: [78.0, 55.333333333333336, 71.33333333333333, 52.666666666666664, 60.666666666666664, 80.66666666666667, 64.0, 69.33333333333333, 88.0, 62.0, 70.0, 48.666666666666664, 80.0, 78.66666666666667]
# task ('lymphovascular_invasion_present', 'HNSC') ==> 66.0 seed 0
# task ('lymphovascular_invasion_present', 'HNSC') ==> 62.0 seed 1
# task ('lymphovascular_invasion_present', 'HNSC') ==> 68.0 seed 2
# Average task performance for channel [512, 128, 64]: [78.0, 55.333333333333336, 71.33333333333333, 52.666666666666664, 60.666666666666664, 80.66666666666667, 64.0, 69.33333333333333, 88.0, 62.0, 70.0, 48.666666666666664, 80.0, 78.66666666666667, 65.33333333333333]
# Not enough number of samples
# task ('oct_embedded', 'CESC') ==> 56.00000000000001 seed 0
# task ('oct_embedded', 'CESC') ==> 56.00000000000001 seed 1
# task ('oct_embedded', 'CESC') ==> 56.00000000000001 seed 2
# Average task performance for channel [512, 128, 64]: [78.0, 55.333333333333336, 71.33333333333333, 52.666666666666664, 60.666666666666664, 80.66666666666667, 64.0, 69.33333333333333, 88.0, 62.0, 70.0, 48.666666666666664, 80.0, 78.66666666666667, 65.33333333333333, 56.00000000000001]
# Not enough number of samples
# Not enough number of samples
# task ('oct_embedded', 'STAD') ==> 57.99999999999999 seed 0
# task ('oct_embedded', 'STAD') ==> 62.0 seed 1
# task ('oct_embedded', 'STAD') ==> 57.99999999999999 seed 2
# Average task performance for channel [512, 128, 64]: [78.0, 55.333333333333336, 71.33333333333333, 52.666666666666664, 60.666666666666664, 80.66666666666667, 64.0, 69.33333333333333, 88.0, 62.0, 70.0, 48.666666666666664, 80.0, 78.66666666666667, 65.33333333333333, 56.00000000000001, 59.333333333333336]
# task ('oct_embedded', 'THCA') ==> 64.0 seed 0
# task ('oct_embedded', 'THCA') ==> 62.0 seed 1
# task ('oct_embedded', 'THCA') ==> 57.99999999999999 seed 2
# Average task performance for channel [512, 128, 64]: [78.0, 55.333333333333336, 71.33333333333333, 52.666666666666664, 60.666666666666664, 80.66666666666667, 64.0, 69.33333333333333, 88.0, 62.0, 70.0, 48.666666666666664, 80.0, 78.66666666666667, 65.33333333333333, 56.00000000000001, 59.333333333333336, 61.333333333333336]
# task ('tumor_tissue_site', 'PCPG') ==> 90.0 seed 0
# task ('tumor_tissue_site', 'PCPG') ==> 92.0 seed 1
# task ('tumor_tissue_site', 'PCPG') ==> 88.0 seed 2
# Average task performance for channel [512, 128, 64]: [78.0, 55.333333333333336, 71.33333333333333, 52.666666666666664, 60.666666666666664, 80.66666666666667, 64.0, 69.33333333333333, 88.0, 62.0, 70.0, 48.666666666666664, 80.0, 78.66666666666667, 65.33333333333333, 56.00000000000001, 59.333333333333336, 61.333333333333336, 90.0]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 44.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 66.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 54.0 seed 0
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 1
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664, 55.333333333333336]
# task ('_EVENT', 'GBMLGG') ==> 72.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664, 55.333333333333336, 69.33333333333333]
# task ('_EVENT', 'LAML') ==> 52.0 seed 0
# task ('_EVENT', 'LAML') ==> 48.0 seed 1
# task ('_EVENT', 'LAML') ==> 50.0 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664, 55.333333333333336, 69.33333333333333, 50.0]
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 0
# task ('_EVENT', 'LUSC') ==> 62.0 seed 1
# task ('_EVENT', 'LUSC') ==> 54.0 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664, 55.333333333333336, 69.33333333333333, 50.0, 58.0]
# task ('_EVENT', 'UCEC') ==> 80.0 seed 0
# task ('_EVENT', 'UCEC') ==> 80.0 seed 1
# task ('_EVENT', 'UCEC') ==> 82.0 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664, 55.333333333333336, 69.33333333333333, 50.0, 58.0, 80.66666666666667]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 56.00000000000001 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 62.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 56.00000000000001 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664, 55.333333333333336, 69.33333333333333, 50.0, 58.0, 80.66666666666667, 58.0]
# task ('alcohol_history_documented', 'HNSC') ==> 72.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 72.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664, 55.333333333333336, 69.33333333333333, 50.0, 58.0, 80.66666666666667, 58.0, 70.66666666666667]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664, 55.333333333333336, 69.33333333333333, 50.0, 58.0, 80.66666666666667, 58.0, 70.66666666666667, 88.0]
# Not enough number of samples
# task ('clinical_stage', 'KIRP') ==> 62.0 seed 0
# task ('clinical_stage', 'KIRP') ==> 66.0 seed 1
# task ('clinical_stage', 'KIRP') ==> 66.0 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664, 55.333333333333336, 69.33333333333333, 50.0, 58.0, 80.66666666666667, 58.0, 70.66666666666667, 88.0, 64.66666666666667]
# task ('colon_polyps_present', 'COADREAD') ==> 70.0 seed 0
# task ('colon_polyps_present', 'COADREAD') ==> 68.0 seed 1
# task ('colon_polyps_present', 'COADREAD') ==> 66.0 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664, 55.333333333333336, 69.33333333333333, 50.0, 58.0, 80.66666666666667, 58.0, 70.66666666666667, 88.0, 64.66666666666667, 68.0]
# Not enough number of samples
# task ('family_history_of_cancer', 'LGG') ==> 57.99999999999999 seed 0
# task ('family_history_of_cancer', 'LGG') ==> 56.00000000000001 seed 1
# task ('family_history_of_cancer', 'LGG') ==> 38.0 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664, 55.333333333333336, 69.33333333333333, 50.0, 58.0, 80.66666666666667, 58.0, 70.66666666666667, 88.0, 64.66666666666667, 68.0, 50.666666666666664]
# task ('gender', 'LIHC') ==> 84.0 seed 0
# task ('gender', 'LIHC') ==> 84.0 seed 1
# task ('gender', 'LIHC') ==> 84.0 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664, 55.333333333333336, 69.33333333333333, 50.0, 58.0, 80.66666666666667, 58.0, 70.66666666666667, 88.0, 64.66666666666667, 68.0, 50.666666666666664, 84.0]
# task ('gender', 'STAD') ==> 80.0 seed 0
# task ('gender', 'STAD') ==> 78.0 seed 1
# task ('gender', 'STAD') ==> 78.0 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664, 55.333333333333336, 69.33333333333333, 50.0, 58.0, 80.66666666666667, 58.0, 70.66666666666667, 88.0, 64.66666666666667, 68.0, 50.666666666666664, 84.0, 78.66666666666667]
# task ('lymphovascular_invasion_present', 'HNSC') ==> 66.0 seed 0
# task ('lymphovascular_invasion_present', 'HNSC') ==> 62.0 seed 1
# task ('lymphovascular_invasion_present', 'HNSC') ==> 66.0 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664, 55.333333333333336, 69.33333333333333, 50.0, 58.0, 80.66666666666667, 58.0, 70.66666666666667, 88.0, 64.66666666666667, 68.0, 50.666666666666664, 84.0, 78.66666666666667, 64.66666666666667]
# Not enough number of samples
# task ('oct_embedded', 'CESC') ==> 56.00000000000001 seed 0
# task ('oct_embedded', 'CESC') ==> 56.00000000000001 seed 1
# task ('oct_embedded', 'CESC') ==> 56.00000000000001 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664, 55.333333333333336, 69.33333333333333, 50.0, 58.0, 80.66666666666667, 58.0, 70.66666666666667, 88.0, 64.66666666666667, 68.0, 50.666666666666664, 84.0, 78.66666666666667, 64.66666666666667, 56.00000000000001]
# Not enough number of samples
# Not enough number of samples
# task ('oct_embedded', 'STAD') ==> 68.0 seed 0
# task ('oct_embedded', 'STAD') ==> 60.0 seed 1
# task ('oct_embedded', 'STAD') ==> 66.0 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664, 55.333333333333336, 69.33333333333333, 50.0, 58.0, 80.66666666666667, 58.0, 70.66666666666667, 88.0, 64.66666666666667, 68.0, 50.666666666666664, 84.0, 78.66666666666667, 64.66666666666667, 56.00000000000001, 64.66666666666667]
# task ('oct_embedded', 'THCA') ==> 68.0 seed 0
# task ('oct_embedded', 'THCA') ==> 62.0 seed 1
# task ('oct_embedded', 'THCA') ==> 64.0 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664, 55.333333333333336, 69.33333333333333, 50.0, 58.0, 80.66666666666667, 58.0, 70.66666666666667, 88.0, 64.66666666666667, 68.0, 50.666666666666664, 84.0, 78.66666666666667, 64.66666666666667, 56.00000000000001, 64.66666666666667, 64.66666666666667]
# task ('tumor_tissue_site', 'PCPG') ==> 92.0 seed 0
# task ('tumor_tissue_site', 'PCPG') ==> 92.0 seed 1
# task ('tumor_tissue_site', 'PCPG') ==> 90.0 seed 2
# Average task performance for channel [256, 128, 32]: [62.666666666666664, 55.333333333333336, 69.33333333333333, 50.0, 58.0, 80.66666666666667, 58.0, 70.66666666666667, 88.0, 64.66666666666667, 68.0, 50.666666666666664, 84.0, 78.66666666666667, 64.66666666666667, 56.00000000000001, 64.66666666666667, 64.66666666666667, 91.33333333333333]
# Channel Average Performace: [68.24561403508771, 66.87719298245615, 67.96491228070174, 67.36842105263159]
# The most optimal number of nodes for 3 number of layers architecture: [128, 64, 32]

# %%
num_layer= 4
channels4 = [[512,256,128,64],[256,128,64,32],[128,64,32,16]] #Best: [256,128,64,32] : 62.833333333333336
channel4_res = []
for channel in channels4:
    task_res = []
    for taskid in tasks_opt[:5]:
        task = meta_dataloader.TCGA.TCGATask(taskid)
        input_size = task._samples.shape[1]
        num_classes = len(collections.Counter(task._labels))
        try:
            train_set, valid_set, test_set = load_sets(task, valid=True)
            seed_res=[]
            for seed in range(0,3):
                MLP_model = MultiLayerPerceptron(seed, input_size, num_classes, num_layer, channel, lr, batch_size, epochs, patience, weight_decay)
                trained_model, train_loss = train(MLP_model, train_set, task.id, False)
                mlp_result = test(trained_model, valid_set)
                print('task {} ==> {} seed {}' .format(taskid, mlp_result, seed))
                seed_res.append(mlp_result)
            task_res.append(np.mean(seed_res))
            print("Average task performance for channel {}: {}" .format(channel, task_res))
        except:
            print("Not enough number of samples")
        
    channel4_res.append(np.mean(task_res))
print("Channel Average Performace: {}" .format(channel4_res))
best_channel_4 = channels4[channel4_res.index(max(channel4_res))]
print("The most optimal number of nodes for 4 number of layers architecture: {}" .format(best_channel_4))
# Out:
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 80.0 seed 2
# Average task performance for channel [512, 256, 128, 64]: [77.33333333333333]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'ESCA') ==> 54.0 seed 1
# task ('_EVENT', 'ESCA') ==> 54.0 seed 2
# Average task performance for channel [512, 256, 128, 64]: [77.33333333333333, 54.666666666666664]
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 56.00000000000001 seed 1
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 2
# Average task performance for channel [512, 256, 128, 64]: [77.33333333333333, 54.666666666666664, 65.33333333333333]
# task ('_EVENT', 'LAML') ==> 52.0 seed 0
# task ('_EVENT', 'LAML') ==> 54.0 seed 1
# task ('_EVENT', 'LAML') ==> 56.00000000000001 seed 2
# Average task performance for channel [512, 256, 128, 64]: [77.33333333333333, 54.666666666666664, 65.33333333333333, 54.0]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 80.0 seed 2
# Average task performance for channel [256, 128, 64, 32]: [78.0]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'ESCA') ==> 54.0 seed 1
# task ('_EVENT', 'ESCA') ==> 54.0 seed 2
# Average task performance for channel [256, 128, 64, 32]: [78.0, 54.666666666666664]
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 64.0 seed 2
# Average task performance for channel [256, 128, 64, 32]: [78.0, 54.666666666666664, 67.33333333333333]
# task ('_EVENT', 'LAML') ==> 54.0 seed 0
# task ('_EVENT', 'LAML') ==> 50.0 seed 1
# task ('_EVENT', 'LAML') ==> 50.0 seed 2
# Average task performance for channel [256, 128, 64, 32]: [78.0, 54.666666666666664, 67.33333333333333, 51.333333333333336]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 54.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 70.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 68.0 seed 2
# Average task performance for channel [128, 64, 32, 16]: [64.0]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 57.99999999999999 seed 0
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 1
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 2
# Average task performance for channel [128, 64, 32, 16]: [64.0, 56.666666666666664]
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 62.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 2
# Average task performance for channel [128, 64, 32, 16]: [64.0, 56.666666666666664, 66.66666666666667]
# task ('_EVENT', 'LAML') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'LAML') ==> 54.0 seed 1
# task ('_EVENT', 'LAML') ==> 57.99999999999999 seed 2
# Average task performance for channel [128, 64, 32, 16]: [64.0, 56.666666666666664, 66.66666666666667, 56.0]
# Channel Average Performace: [62.83333333333333, 62.833333333333336, 60.83333333333333]
# The most optimal number of nodes for 2 number of layers architecture: [256, 128, 64, 32]

# %% [markdown]
# # Learning Rate Optimization

# %%
weight_decay = 0.00005
batch_size = 32
epochs=100
num_layer = 2
channels = [128,64]

# %%
lr_list = [0.00001,0.0001,0.001,0.01] #0.0001 : 68.33333333333333
lr_res = []

for learning_rate in lr_list:
    task_res = []
    for taskid in tasks_opt[:10]:
        task = meta_dataloader.TCGA.TCGATask(taskid)
        input_size = task._samples.shape[1]
        num_classes = len(collections.Counter(task._labels))
        try:
            train_set, valid_set, test_set = load_sets(task, valid=True)
            seed_res=[]
            for seed in range(0,4):
                MLP_model = MultiLayerPerceptron(seed, input_size, num_classes, num_layer, channels, learning_rate, batch_size, epochs, patience, weight_decay)
                trained_model, train_loss = train(MLP_model, train_set, task.id, False)
                mlp_result = test(trained_model, valid_set)
                print('task {} ==> {} seed {}' .format(taskid, mlp_result, seed))
                seed_res.append(mlp_result)
            task_res.append(np.mean(seed_res))
            print("Average task performance for channel {}: {}" .format(learning_rate, task_res))
        except:
            print("Not enough number of samples")
    lr_res.append(np.mean(task_res))
print("Learning rate Average Performace over tasks: {}" .format(lr_res))
best_lr = lr_list[lr_res.index(max(lr_res))]
print("The most optimal learning rate: {}" .format(best_lr))
# Out:
# task ('PAM50Call_RNAseq', 'BRCA') ==> 70.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 74.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 74.0 seed 2
# task ('PAM50Call_RNAseq', 'BRCA') ==> 74.0 seed 3
# Average task performance for channel 1e-05: [73.0]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'ESCA') ==> 64.0 seed 1
# task ('_EVENT', 'ESCA') ==> 60.0 seed 2
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 3
# Average task performance for channel 1e-05: [73.0, 59.0]
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 66.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 64.0 seed 2
# task ('_EVENT', 'GBMLGG') ==> 64.0 seed 3
# Average task performance for channel 1e-05: [73.0, 59.0, 66.0]
# task ('_EVENT', 'LAML') ==> 50.0 seed 0
# task ('_EVENT', 'LAML') ==> 60.0 seed 1
# task ('_EVENT', 'LAML') ==> 57.99999999999999 seed 2
# task ('_EVENT', 'LAML') ==> 60.0 seed 3
# Average task performance for channel 1e-05: [73.0, 59.0, 66.0, 57.0]
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 0
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'LUSC') ==> 60.0 seed 2
# task ('_EVENT', 'LUSC') ==> 56.00000000000001 seed 3
# Average task performance for channel 1e-05: [73.0, 59.0, 66.0, 57.0, 58.0]
# task ('_EVENT', 'UCEC') ==> 82.0 seed 0
# task ('_EVENT', 'UCEC') ==> 82.0 seed 1
# task ('_EVENT', 'UCEC') ==> 80.0 seed 2
# task ('_EVENT', 'UCEC') ==> 82.0 seed 3
# Average task performance for channel 1e-05: [73.0, 59.0, 66.0, 57.0, 58.0, 81.5]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 57.99999999999999 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 54.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 56.00000000000001 seed 2
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 54.0 seed 3
# Average task performance for channel 1e-05: [73.0, 59.0, 66.0, 57.0, 58.0, 81.5, 55.5]
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 2
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 3
# Average task performance for channel 1e-05: [73.0, 59.0, 66.0, 57.0, 58.0, 81.5, 55.5, 70.0]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 2
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 3
# Average task performance for channel 1e-05: [73.0, 59.0, 66.0, 57.0, 58.0, 81.5, 55.5, 70.0, 88.0]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 74.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 2
# task ('PAM50Call_RNAseq', 'BRCA') ==> 68.0 seed 3
# Average task performance for channel 0.0001: [74.0]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 60.0 seed 0
# task ('_EVENT', 'ESCA') ==> 62.0 seed 1
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 2
# task ('_EVENT', 'ESCA') ==> 62.0 seed 3
# Average task performance for channel 0.0001: [74.0, 60.0]
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 72.0 seed 2
# task ('_EVENT', 'GBMLGG') ==> 64.0 seed 3
# Average task performance for channel 0.0001: [74.0, 60.0, 68.0]
# task ('_EVENT', 'LAML') ==> 57.99999999999999 seed 0
# task ('_EVENT', 'LAML') ==> 56.00000000000001 seed 1
# task ('_EVENT', 'LAML') ==> 50.0 seed 2
# task ('_EVENT', 'LAML') ==> 60.0 seed 3
# Average task performance for channel 0.0001: [74.0, 60.0, 68.0, 56.0]
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 0
# task ('_EVENT', 'LUSC') ==> 56.00000000000001 seed 1
# task ('_EVENT', 'LUSC') ==> 60.0 seed 2
# task ('_EVENT', 'LUSC') ==> 62.0 seed 3
# Average task performance for channel 0.0001: [74.0, 60.0, 68.0, 56.0, 59.0]
# task ('_EVENT', 'UCEC') ==> 82.0 seed 0
# task ('_EVENT', 'UCEC') ==> 82.0 seed 1
# task ('_EVENT', 'UCEC') ==> 82.0 seed 2
# task ('_EVENT', 'UCEC') ==> 80.0 seed 3
# Average task performance for channel 0.0001: [74.0, 60.0, 68.0, 56.0, 59.0, 81.5]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 57.99999999999999 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 57.99999999999999 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 62.0 seed 2
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 60.0 seed 3
# Average task performance for channel 0.0001: [74.0, 60.0, 68.0, 56.0, 59.0, 81.5, 59.5]
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 2
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 3
# Average task performance for channel 0.0001: [74.0, 60.0, 68.0, 56.0, 59.0, 81.5, 59.5, 69.0]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 2
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 3
# Average task performance for channel 0.0001: [74.0, 60.0, 68.0, 56.0, 59.0, 81.5, 59.5, 69.0, 88.0]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 72.0 seed 2
# task ('PAM50Call_RNAseq', 'BRCA') ==> 70.0 seed 3
# Average task performance for channel 0.001: [74.0]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 54.0 seed 0
# task ('_EVENT', 'ESCA') ==> 54.0 seed 1
# task ('_EVENT', 'ESCA') ==> 57.99999999999999 seed 2
# task ('_EVENT', 'ESCA') ==> 54.0 seed 3
# Average task performance for channel 0.001: [74.0, 55.0]
# task ('_EVENT', 'GBMLGG') ==> 62.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 2
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 3
# Average task performance for channel 0.001: [74.0, 55.0, 67.5]
# task ('_EVENT', 'LAML') ==> 54.0 seed 0
# task ('_EVENT', 'LAML') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'LAML') ==> 57.99999999999999 seed 2
# task ('_EVENT', 'LAML') ==> 52.0 seed 3
# Average task performance for channel 0.001: [74.0, 55.0, 67.5, 55.5]
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 0
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'LUSC') ==> 60.0 seed 2
# task ('_EVENT', 'LUSC') ==> 60.0 seed 3
# Average task performance for channel 0.001: [74.0, 55.0, 67.5, 55.5, 59.0]
# task ('_EVENT', 'UCEC') ==> 82.0 seed 0
# task ('_EVENT', 'UCEC') ==> 80.0 seed 1
# task ('_EVENT', 'UCEC') ==> 80.0 seed 2
# task ('_EVENT', 'UCEC') ==> 80.0 seed 3
# Average task performance for channel 0.001: [74.0, 55.0, 67.5, 55.5, 59.0, 80.5]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 66.0 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 60.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 62.0 seed 2
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 66.0 seed 3
# Average task performance for channel 0.001: [74.0, 55.0, 67.5, 55.5, 59.0, 80.5, 63.5]
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 2
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 3
# Average task performance for channel 0.001: [74.0, 55.0, 67.5, 55.5, 59.0, 80.5, 63.5, 69.0]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 2
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 3
# Average task performance for channel 0.001: [74.0, 55.0, 67.5, 55.5, 59.0, 80.5, 63.5, 69.0, 88.0]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 62.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 57.99999999999999 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 48.0 seed 2
# task ('PAM50Call_RNAseq', 'BRCA') ==> 48.0 seed 3
# Average task performance for channel 0.01: [54.0]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 57.99999999999999 seed 0
# task ('_EVENT', 'ESCA') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'ESCA') ==> 57.99999999999999 seed 2
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 3
# Average task performance for channel 0.01: [54.0, 57.49999999999999]
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 62.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 2
# task ('_EVENT', 'GBMLGG') ==> 62.0 seed 3
# Average task performance for channel 0.01: [54.0, 57.49999999999999, 65.0]
# task ('_EVENT', 'LAML') ==> 64.0 seed 0
# task ('_EVENT', 'LAML') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'LAML') ==> 50.0 seed 2
# task ('_EVENT', 'LAML') ==> 48.0 seed 3
# Average task performance for channel 0.01: [54.0, 57.49999999999999, 65.0, 55.0]
# task ('_EVENT', 'LUSC') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'LUSC') ==> 60.0 seed 1
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 2
# task ('_EVENT', 'LUSC') ==> 56.00000000000001 seed 3
# Average task performance for channel 0.01: [54.0, 57.49999999999999, 65.0, 55.0, 57.5]
# task ('_EVENT', 'UCEC') ==> 82.0 seed 0
# task ('_EVENT', 'UCEC') ==> 80.0 seed 1
# task ('_EVENT', 'UCEC') ==> 82.0 seed 2
# task ('_EVENT', 'UCEC') ==> 82.0 seed 3
# Average task performance for channel 0.01: [54.0, 57.49999999999999, 65.0, 55.0, 57.5, 81.5]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 46.0 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 40.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 52.0 seed 2
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 38.0 seed 3
# Average task performance for channel 0.01: [54.0, 57.49999999999999, 65.0, 55.0, 57.5, 81.5, 44.0]
# task ('alcohol_history_documented', 'HNSC') ==> 66.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 2
# task ('alcohol_history_documented', 'HNSC') ==> 66.0 seed 3
# Average task performance for channel 0.01: [54.0, 57.49999999999999, 65.0, 55.0, 57.5, 81.5, 44.0, 67.5]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 2
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 3
# Average task performance for channel 0.01: [54.0, 57.49999999999999, 65.0, 55.0, 57.5, 81.5, 44.0, 67.5, 88.0]
# Learning rate Average Performace over tasks: [67.55555555555556, 68.33333333333333, 68.0, 63.333333333333336]
# The most optimal learning rate: 0.0001

# %% [markdown]
# # Number of epochs experiments

# %%
weight_decay = 0.00005
batch_size = 32
lr= 0.0001 # best_lr
num_layer = 2 # best num_layer
channels = [128,64] # best channels

# %%
epoch_list = [100,250,500]
epoch_res = []

for e in epoch_list:
    task_res = []
    for taskid in tasks_opt[:10]:
        task = meta_dataloader.TCGA.TCGATask(taskid)
        input_size = task._samples.shape[1]
        num_classes = len(collections.Counter(task._labels))
        try:
            train_set, valid_set, test_set = load_sets(task, valid=True)
            seed_res=[]
            for seed in range(0,4):
                MLP_model = MultiLayerPerceptron(seed, input_size, num_classes, num_layer, channels, lr, batch_size, e, patience, weight_decay)
                trained_model, train_loss = train(MLP_model, train_set, task.id, False)
                mlp_result = test(trained_model, valid_set)
                print('task {} ==> {} seed {}' .format(taskid, mlp_result, seed))
                seed_res.append(mlp_result)
            task_res.append(np.mean(seed_res))
            print("Average task performance for epoch {}: {}" .format(e, task_res))
        except:
            print("Not enough number of samples")
        
    epoch_res.append(np.mean(task_res))
print("Epoch Average Performace over tasks: {}" .format(epoch_res))
best_epoch = epoch_list[epoch_res.index(max(epoch_res))]
print("The most optimal number of epochs: {}" .format(best_epoch))
# Out:
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 72.0 seed 2
# task ('PAM50Call_RNAseq', 'BRCA') ==> 70.0 seed 3
# Average task performance for epoch 100: [74.0]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 54.0 seed 0
# task ('_EVENT', 'ESCA') ==> 54.0 seed 1
# task ('_EVENT', 'ESCA') ==> 57.99999999999999 seed 2
# task ('_EVENT', 'ESCA') ==> 54.0 seed 3
# Average task performance for epoch 100: [74.0, 55.0]
# task ('_EVENT', 'GBMLGG') ==> 62.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 2
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 3
# Average task performance for epoch 100: [74.0, 55.0, 67.5]
# task ('_EVENT', 'LAML') ==> 54.0 seed 0
# task ('_EVENT', 'LAML') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'LAML') ==> 57.99999999999999 seed 2
# task ('_EVENT', 'LAML') ==> 52.0 seed 3
# Average task performance for epoch 100: [74.0, 55.0, 67.5, 55.5]
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 0
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'LUSC') ==> 60.0 seed 2
# task ('_EVENT', 'LUSC') ==> 60.0 seed 3
# Average task performance for epoch 100: [74.0, 55.0, 67.5, 55.5, 59.0]
# task ('_EVENT', 'UCEC') ==> 82.0 seed 0
# task ('_EVENT', 'UCEC') ==> 80.0 seed 1
# task ('_EVENT', 'UCEC') ==> 80.0 seed 2
# task ('_EVENT', 'UCEC') ==> 80.0 seed 3
# Average task performance for epoch 100: [74.0, 55.0, 67.5, 55.5, 59.0, 80.5]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 66.0 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 60.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 62.0 seed 2
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 66.0 seed 3
# Average task performance for epoch 100: [74.0, 55.0, 67.5, 55.5, 59.0, 80.5, 63.5]
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 2
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 3
# Average task performance for epoch 100: [74.0, 55.0, 67.5, 55.5, 59.0, 80.5, 63.5, 69.0]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 2
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 3
# Average task performance for epoch 100: [74.0, 55.0, 67.5, 55.5, 59.0, 80.5, 63.5, 69.0, 88.0]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 2
# task ('PAM50Call_RNAseq', 'BRCA') ==> 70.0 seed 3
# Average task performance for epoch 250: [75.5]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 54.0 seed 0
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 1
# task ('_EVENT', 'ESCA') ==> 54.0 seed 2
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 3
# Average task performance for epoch 250: [75.5, 55.0]
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 2
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 3
# Average task performance for epoch 250: [75.5, 55.0, 68.5]
# task ('_EVENT', 'LAML') ==> 52.0 seed 0
# task ('_EVENT', 'LAML') ==> 52.0 seed 1
# task ('_EVENT', 'LAML') ==> 50.0 seed 2
# task ('_EVENT', 'LAML') ==> 50.0 seed 3
# Average task performance for epoch 250: [75.5, 55.0, 68.5, 51.0]
# task ('_EVENT', 'LUSC') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'LUSC') ==> 56.00000000000001 seed 2
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 3
# Average task performance for epoch 250: [75.5, 55.0, 68.5, 51.0, 57.0]
# task ('_EVENT', 'UCEC') ==> 80.0 seed 0
# task ('_EVENT', 'UCEC') ==> 80.0 seed 1
# task ('_EVENT', 'UCEC') ==> 80.0 seed 2
# task ('_EVENT', 'UCEC') ==> 80.0 seed 3
# Average task performance for epoch 250: [75.5, 55.0, 68.5, 51.0, 57.0, 80.0]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 66.0 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 62.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 64.0 seed 2
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 68.0 seed 3
# Average task performance for epoch 250: [75.5, 55.0, 68.5, 51.0, 57.0, 80.0, 65.0]
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 2
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 3
# Average task performance for epoch 250: [75.5, 55.0, 68.5, 51.0, 57.0, 80.0, 65.0, 69.5]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 2
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 3
# Average task performance for epoch 250: [75.5, 55.0, 68.5, 51.0, 57.0, 80.0, 65.0, 69.5, 88.0]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 72.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 2
# task ('PAM50Call_RNAseq', 'BRCA') ==> 70.0 seed 3
# Average task performance for epoch 500: [74.5]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 54.0 seed 0
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 1
# task ('_EVENT', 'ESCA') ==> 54.0 seed 2
# task ('_EVENT', 'ESCA') ==> 54.0 seed 3
# Average task performance for epoch 500: [74.5, 54.5]
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 2
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 3
# Average task performance for epoch 500: [74.5, 54.5, 68.5]
# task ('_EVENT', 'LAML') ==> 48.0 seed 0
# task ('_EVENT', 'LAML') ==> 54.0 seed 1
# task ('_EVENT', 'LAML') ==> 50.0 seed 2
# task ('_EVENT', 'LAML') ==> 48.0 seed 3
# Average task performance for epoch 500: [74.5, 54.5, 68.5, 50.0]
# task ('_EVENT', 'LUSC') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'LUSC') ==> 56.00000000000001 seed 2
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 3
# Average task performance for epoch 500: [74.5, 54.5, 68.5, 50.0, 57.0]
# task ('_EVENT', 'UCEC') ==> 82.0 seed 0
# task ('_EVENT', 'UCEC') ==> 80.0 seed 1
# task ('_EVENT', 'UCEC') ==> 80.0 seed 2
# task ('_EVENT', 'UCEC') ==> 80.0 seed 3
# Average task performance for epoch 500: [74.5, 54.5, 68.5, 50.0, 57.0, 80.5]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 68.0 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 60.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 64.0 seed 2
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 66.0 seed 3
# Average task performance for epoch 500: [74.5, 54.5, 68.5, 50.0, 57.0, 80.5, 64.5]
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 2
# task ('alcohol_history_documented', 'HNSC') ==> 72.0 seed 3
# Average task performance for epoch 500: [74.5, 54.5, 68.5, 50.0, 57.0, 80.5, 64.5, 70.0]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 86.0 seed 2
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 3
# Average task performance for epoch 500: [74.5, 54.5, 68.5, 50.0, 57.0, 80.5, 64.5, 70.0, 87.5]
# Epoch Average Performace over tasks: [68.0, 67.72222222222223, 67.44444444444444]
# The most optimal number of epochs: 100

# %% [markdown]
# # Weight-decay Experiment

# %%
epochs = 100
batch_size = 32
lr= 0.0001 # best_lr
num_layer = 2 # best num_layer
channels = [128,64] # best channels

# %%
wd_list=[0, 0.00005, 0.0005, 0.005, 0.05]
wd = []

for wd in wd_list:
    task_res = []
    for taskid in tasks_opt[:10]:
        task = meta_dataloader.TCGA.TCGATask(taskid)
        input_size = task._samples.shape[1]
        num_classes = len(collections.Counter(task._labels))
        try:
            train_set, valid_set, test_set = load_sets(task, valid=True)
            seed_res=[]
            for seed in range(0,4):
                MLP_model = MultiLayerPerceptron(seed, input_size, num_classes, num_layer, channels, lr, batch_size, epochs, patience, wd)
                trained_model, train_loss = train(MLP_model, train_set, task.id, False)
                mlp_result = test(trained_model, valid_set)
                print('task {} ==> {} seed {}' .format(taskid, mlp_result, seed))
                seed_res.append(mlp_result)
            task_res.append(np.mean(seed_res))
            print("Average task performance for weight decay {}: {}" .format(wd, task_res))
        except:
            print("Not enough number of samples")
        
    wd_res.append(np.mean(task_res))
print("Weight Decay Average Performace: {}" .format(wd_res))
best_wd = wd_list[wd_res.index(max(wd_res))]
print("The most optimal value of weight decay: {}" .format(best_wd))
# Out:
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 74.0 seed 2
# task ('PAM50Call_RNAseq', 'BRCA') ==> 72.0 seed 3
# Average task performance for weight decay 0: [75.5]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 62.0 seed 0
# task ('_EVENT', 'ESCA') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 2
# task ('_EVENT', 'ESCA') ==> 57.99999999999999 seed 3
# Average task performance for weight decay 0: [75.5, 58.5]
# task ('_EVENT', 'GBMLGG') ==> 66.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 2
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 3
# Average task performance for weight decay 0: [75.5, 58.5, 67.5]
# task ('_EVENT', 'LAML') ==> 57.99999999999999 seed 0
# task ('_EVENT', 'LAML') ==> 50.0 seed 1
# task ('_EVENT', 'LAML') ==> 57.99999999999999 seed 2
# task ('_EVENT', 'LAML') ==> 56.00000000000001 seed 3
# Average task performance for weight decay 0: [75.5, 58.5, 67.5, 55.5]
# task ('_EVENT', 'LUSC') ==> 64.0 seed 0
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 2
# task ('_EVENT', 'LUSC') ==> 56.00000000000001 seed 3
# Average task performance for weight decay 0: [75.5, 58.5, 67.5, 55.5, 59.0]
# task ('_EVENT', 'UCEC') ==> 82.0 seed 0
# task ('_EVENT', 'UCEC') ==> 82.0 seed 1
# task ('_EVENT', 'UCEC') ==> 82.0 seed 2
# task ('_EVENT', 'UCEC') ==> 82.0 seed 3
# Average task performance for weight decay 0: [75.5, 58.5, 67.5, 55.5, 59.0, 82.0]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 56.00000000000001 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 60.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 64.0 seed 2
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 68.0 seed 3
# Average task performance for weight decay 0: [75.5, 58.5, 67.5, 55.5, 59.0, 82.0, 62.0]
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 72.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 2
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 3
# Average task performance for weight decay 0: [75.5, 58.5, 67.5, 55.5, 59.0, 82.0, 62.0, 69.5]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 2
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 3
# Average task performance for weight decay 0: [75.5, 58.5, 67.5, 55.5, 59.0, 82.0, 62.0, 69.5, 88.0]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 74.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 2
# task ('PAM50Call_RNAseq', 'BRCA') ==> 68.0 seed 3
# Average task performance for weight decay 5e-05: [74.0]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 60.0 seed 0
# task ('_EVENT', 'ESCA') ==> 62.0 seed 1
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 2
# task ('_EVENT', 'ESCA') ==> 62.0 seed 3
# Average task performance for weight decay 5e-05: [74.0, 60.0]
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 72.0 seed 2
# task ('_EVENT', 'GBMLGG') ==> 64.0 seed 3
# Average task performance for weight decay 5e-05: [74.0, 60.0, 68.0]
# task ('_EVENT', 'LAML') ==> 57.99999999999999 seed 0
# task ('_EVENT', 'LAML') ==> 56.00000000000001 seed 1
# task ('_EVENT', 'LAML') ==> 50.0 seed 2
# task ('_EVENT', 'LAML') ==> 60.0 seed 3
# Average task performance for weight decay 5e-05: [74.0, 60.0, 68.0, 56.0]
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 0
# task ('_EVENT', 'LUSC') ==> 56.00000000000001 seed 1
# task ('_EVENT', 'LUSC') ==> 60.0 seed 2
# task ('_EVENT', 'LUSC') ==> 62.0 seed 3
# Average task performance for weight decay 5e-05: [74.0, 60.0, 68.0, 56.0, 59.0]
# task ('_EVENT', 'UCEC') ==> 82.0 seed 0
# task ('_EVENT', 'UCEC') ==> 82.0 seed 1
# task ('_EVENT', 'UCEC') ==> 82.0 seed 2
# task ('_EVENT', 'UCEC') ==> 80.0 seed 3
# Average task performance for weight decay 5e-05: [74.0, 60.0, 68.0, 56.0, 59.0, 81.5]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 57.99999999999999 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 57.99999999999999 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 62.0 seed 2
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 60.0 seed 3
# Average task performance for weight decay 5e-05: [74.0, 60.0, 68.0, 56.0, 59.0, 81.5, 59.5]
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 2
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 3
# Average task performance for weight decay 5e-05: [74.0, 60.0, 68.0, 56.0, 59.0, 81.5, 59.5, 69.0]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 2
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 3
# Average task performance for weight decay 5e-05: [74.0, 60.0, 68.0, 56.0, 59.0, 81.5, 59.5, 69.0, 88.0]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 70.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 2
# task ('PAM50Call_RNAseq', 'BRCA') ==> 72.0 seed 3
# Average task performance for weight decay 0.0005: [74.0]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'ESCA') ==> 54.0 seed 1
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 2
# task ('_EVENT', 'ESCA') ==> 54.0 seed 3
# Average task performance for weight decay 0.0005: [74.0, 55.0]
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 2
# task ('_EVENT', 'GBMLGG') ==> 66.0 seed 3
# Average task performance for weight decay 0.0005: [74.0, 55.0, 67.5]
# task ('_EVENT', 'LAML') ==> 57.99999999999999 seed 0
# task ('_EVENT', 'LAML') ==> 60.0 seed 1
# task ('_EVENT', 'LAML') ==> 48.0 seed 2
# task ('_EVENT', 'LAML') ==> 56.00000000000001 seed 3
# Average task performance for weight decay 0.0005: [74.0, 55.0, 67.5, 55.5]
# task ('_EVENT', 'LUSC') ==> 64.0 seed 0
# task ('_EVENT', 'LUSC') ==> 60.0 seed 1
# task ('_EVENT', 'LUSC') ==> 60.0 seed 2
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 3
# Average task performance for weight decay 0.0005: [74.0, 55.0, 67.5, 55.5, 60.5]
# task ('_EVENT', 'UCEC') ==> 82.0 seed 0
# task ('_EVENT', 'UCEC') ==> 82.0 seed 1
# task ('_EVENT', 'UCEC') ==> 82.0 seed 2
# task ('_EVENT', 'UCEC') ==> 82.0 seed 3
# Average task performance for weight decay 0.0005: [74.0, 55.0, 67.5, 55.5, 60.5, 82.0]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 57.99999999999999 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 64.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 66.0 seed 2
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 64.0 seed 3
# Average task performance for weight decay 0.0005: [74.0, 55.0, 67.5, 55.5, 60.5, 82.0, 63.0]
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 76.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 2
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 3
# Average task performance for weight decay 0.0005: [74.0, 55.0, 67.5, 55.5, 60.5, 82.0, 63.0, 70.0]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 86.0 seed 2
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 3
# Average task performance for weight decay 0.0005: [74.0, 55.0, 67.5, 55.5, 60.5, 82.0, 63.0, 70.0, 87.5]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 72.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 2
# task ('PAM50Call_RNAseq', 'BRCA') ==> 70.0 seed 3
# Average task performance for weight decay 0.005: [74.0]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'ESCA') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 2
# task ('_EVENT', 'ESCA') ==> 57.99999999999999 seed 3
# Average task performance for weight decay 0.005: [74.0, 57.0]
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 2
# task ('_EVENT', 'GBMLGG') ==> 70.0 seed 3
# Average task performance for weight decay 0.005: [74.0, 57.0, 68.5]
# task ('_EVENT', 'LAML') ==> 57.99999999999999 seed 0
# task ('_EVENT', 'LAML') ==> 56.00000000000001 seed 1
# task ('_EVENT', 'LAML') ==> 56.00000000000001 seed 2
# task ('_EVENT', 'LAML') ==> 52.0 seed 3
# Average task performance for weight decay 0.005: [74.0, 57.0, 68.5, 55.5]
# task ('_EVENT', 'LUSC') ==> 60.0 seed 0
# task ('_EVENT', 'LUSC') ==> 60.0 seed 1
# task ('_EVENT', 'LUSC') ==> 62.0 seed 2
# task ('_EVENT', 'LUSC') ==> 56.00000000000001 seed 3
# Average task performance for weight decay 0.005: [74.0, 57.0, 68.5, 55.5, 59.5]
# task ('_EVENT', 'UCEC') ==> 82.0 seed 0
# task ('_EVENT', 'UCEC') ==> 82.0 seed 1
# task ('_EVENT', 'UCEC') ==> 80.0 seed 2
# task ('_EVENT', 'UCEC') ==> 80.0 seed 3
# Average task performance for weight decay 0.005: [74.0, 57.0, 68.5, 55.5, 59.5, 81.0]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 62.0 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 60.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 62.0 seed 2
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 66.0 seed 3
# Average task performance for weight decay 0.005: [74.0, 57.0, 68.5, 55.5, 59.5, 81.0, 62.5]
# task ('alcohol_history_documented', 'HNSC') ==> 72.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 2
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 3
# Average task performance for weight decay 0.005: [74.0, 57.0, 68.5, 55.5, 59.5, 81.0, 62.5, 69.5]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 2
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 3
# Average task performance for weight decay 0.005: [74.0, 57.0, 68.5, 55.5, 59.5, 81.0, 62.5, 69.5, 88.0]
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 0
# task ('PAM50Call_RNAseq', 'BRCA') ==> 68.0 seed 1
# task ('PAM50Call_RNAseq', 'BRCA') ==> 78.0 seed 2
# task ('PAM50Call_RNAseq', 'BRCA') ==> 76.0 seed 3
# Average task performance for weight decay 0.05: [74.5]
# Not enough number of samples
# task ('_EVENT', 'ESCA') ==> 56.00000000000001 seed 0
# task ('_EVENT', 'ESCA') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'ESCA') ==> 60.0 seed 2
# task ('_EVENT', 'ESCA') ==> 57.99999999999999 seed 3
# Average task performance for weight decay 0.05: [74.5, 58.0]
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 0
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 1
# task ('_EVENT', 'GBMLGG') ==> 68.0 seed 2
# task ('_EVENT', 'GBMLGG') ==> 66.0 seed 3
# Average task performance for weight decay 0.05: [74.5, 58.0, 67.5]
# task ('_EVENT', 'LAML') ==> 60.0 seed 0
# task ('_EVENT', 'LAML') ==> 62.0 seed 1
# task ('_EVENT', 'LAML') ==> 52.0 seed 2
# task ('_EVENT', 'LAML') ==> 52.0 seed 3
# Average task performance for weight decay 0.05: [74.5, 58.0, 67.5, 56.5]
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 0
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 1
# task ('_EVENT', 'LUSC') ==> 64.0 seed 2
# task ('_EVENT', 'LUSC') ==> 57.99999999999999 seed 3
# Average task performance for weight decay 0.05: [74.5, 58.0, 67.5, 56.5, 59.5]
# task ('_EVENT', 'UCEC') ==> 82.0 seed 0
# task ('_EVENT', 'UCEC') ==> 82.0 seed 1
# task ('_EVENT', 'UCEC') ==> 82.0 seed 2
# task ('_EVENT', 'UCEC') ==> 80.0 seed 3
# Average task performance for weight decay 0.05: [74.5, 58.0, 67.5, 56.5, 59.5, 81.5]
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 62.0 seed 0
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 62.0 seed 1
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 64.0 seed 2
# task ('_PANCAN_DNAMethyl_LUSC', 'LUSC') ==> 60.0 seed 3
# Average task performance for weight decay 0.05: [74.5, 58.0, 67.5, 56.5, 59.5, 81.5, 62.0]
# task ('alcohol_history_documented', 'HNSC') ==> 72.0 seed 0
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 1
# task ('alcohol_history_documented', 'HNSC') ==> 70.0 seed 2
# task ('alcohol_history_documented', 'HNSC') ==> 68.0 seed 3
# Average task performance for weight decay 0.05: [74.5, 58.0, 67.5, 56.5, 59.5, 81.5, 62.0, 70.0]
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 0
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 1
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 2
# task ('biochemical_recurrence', 'PRAD') ==> 88.0 seed 3
# Average task performance for weight decay 0.05: [74.5, 58.0, 67.5, 56.5, 59.5, 81.5, 62.0, 70.0, 88.0]
# Weight Decay Average Performace: [68.61111111111111, 68.33333333333333, 68.33333333333333, 68.38888888888889, 68.61111111111111]
# The most optimal value of weight decay: 0

# %%
#for lr in [0.000001,0.00001,0.0001,0.001,0.01]:
#    for seed in [0,1]:
#        model = models.mlp.MLP(name="MLP_lay2_chan512",
                               num_layer=1, 
                               channels=256, 
                               lr=lr,
                               patience=50,
                               cuda=True,
                               metric=sklearn.metrics.accuracy_score,
                               verbose=False,
                               seed=seed)

#        model.fit(X_train, y_train)
#
#        y_valid_pred = model.predict(X_valid)
#        print(seed, lr, sklearn.metrics.accuracy_score(y_valid, np.argmax(y_valid_pred,axis=1)))
